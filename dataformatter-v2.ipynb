# %%
import numpy as np
import re
from collections import Counter

# %%
fulltext = list(np.load('data//numpy//fullstrings.npy'))
titles = list(np.load('data//numpy//titles.npy'))
c2i = np.load('data//numpy//c2i.npy').item()
i2c = np.load('data//numpy//i2c.npy').item()

# %% [markdown]
# ## generate batches

# %%
def cardGenerator(cardtext, title, windowsize, c2i=c2i, debug=False):
        
    i = 0
    indices = list(np.random.permutation(len(cardtext)))
    idx = indices[i]

    # pregenerate warmup sequence
    warmup = ''
    while len(warmup) < windowsize:
        warmup += title[idx]
    
    warmup = list(warmup[-windowsize:])
    
    # sequence start
    sequence = list(cardtext[idx])
    
    # create matrix
    x = []
    y = []
    
    sequence = warmup + sequence
    
    if debug:
        sequence = sequence
    else:
        sequence = [c2i[c] for c in sequence]
    
    # main iterator
    while True:
        
        # generate batch (of cards_per_batch cards)
        while len(sequence) > windowsize:
            x.append(np.array(sequence[:windowsize]))
            y.append(sequence[windowsize])
            sequence.pop(0)
        
        # generate batch_size worth of window-shifted data
        # reshape for sparse_categorical_crossentropy
        sequence = []
        y = np.array(y)
        y = y[:, np.newaxis]
        # yield and reset
        yield(np.asarray(x), y)
        x, y = [], []
        
        # check for too long, reset
        if i+1 > len(indices):
            indices = np.random.permutation(len(cardtext))
            i = 0
            idx = indices[i]
        else:
            i += 1
            idx = indices[i]
            
        # pregenerate new warmup sequence
        warmup = ''
        while len(warmup) < windowsize:
            warmup += title[idx]

        warmup = list(warmup[-windowsize:])

        # sequence start
        sequence = list(cardtext[idx])

        # create matrix
        x = []
        y = []

        sequence = warmup + sequence

        if debug:
            sequence = sequence
        else:
            sequence = [c2i[c] for c in sequence]

# %%
# stress test : batch of 5000 x 2000 = over all cards at least once
# itr = cardGenerator(cardtext, 5, 5000, debug=True)
# for i in range(2000):
#     x, y = next(itr)

# %%
itr = cardGenerator(fulltext, titles, 10, debug=True)

# %%
x, y = next(itr)
print(x.shape, y.shape)
for z in range(len(x)):
    print(x[z], y[z])
# Out:
# (1206, 10) (1206, 1)
# ['v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's'] ['Ⓣ']
# ['e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's' 'Ⓣ'] ['a']
# ['r' 's' 'a' 't' 'i' 'o' 'n' 's' 'Ⓣ' 'a'] [' ']
# ['s' 'a' 't' 'i' 'o' 'n' 's' 'Ⓣ' 'a' ' '] ['t']
# ['a' 't' 'i' 'o' 'n' 's' 'Ⓣ' 'a' ' ' 't'] ['a']
# ['t' 'i' 'o' 'n' 's' 'Ⓣ' 'a' ' ' 't' 'a'] ['x']
# ['i' 'o' 'n' 's' 'Ⓣ' 'a' ' ' 't' 'a' 'x'] ['o']
# ['o' 'n' 's' 'Ⓣ' 'a' ' ' 't' 'a' 'x' 'o'] ['n']
# ['n' 's' 'Ⓣ' 'a' ' ' 't' 'a' 'x' 'o' 'n'] ['o']
# ['s' 'Ⓣ' 'a' ' ' 't' 'a' 'x' 'o' 'n' 'o'] ['m']
# ['Ⓣ' 'a' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm'] ['y']
# ['a' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y'] [' ']
# [' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' '] ['o']
# ['t' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 'o'] ['f']
# ['a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 'o' 'f'] [' ']
# ['x' 'o' 'n' 'o' 'm' 'y' ' ' 'o' 'f' ' '] ['i']
# ['o' 'n' 'o' 'm' 'y' ' ' 'o' 'f' ' ' 'i'] ['n']
# ['n' 'o' 'm' 'y' ' ' 'o' 'f' ' ' 'i' 'n'] ['s']
# ['o' 'm' 'y' ' ' 'o' 'f' ' ' 'i' 'n' 's'] ['t']
# ['m' 'y' ' ' 'o' 'f' ' ' 'i' 'n' 's' 't'] ['r']
# ['y' ' ' 'o' 'f' ' ' 'i' 'n' 's' 't' 'r'] ['u']
# [' ' 'o' 'f' ' ' 'i' 'n' 's' 't' 'r' 'u'] ['c']
# ['o' 'f' ' ' 'i' 'n' 's' 't' 'r' 'u' 'c'] ['t']
# ['f' ' ' 'i' 'n' 's' 't' 'r' 'u' 'c' 't'] ['i']
# [' ' 'i' 'n' 's' 't' 'r' 'u' 'c' 't' 'i'] ['o']
# ['i' 'n' 's' 't' 'r' 'u' 'c' 't' 'i' 'o'] ['n']
# ['n' 's' 't' 'r' 'u' 'c' 't' 'i' 'o' 'n'] ['a']
# ['s' 't' 'r' 'u' 'c' 't' 'i' 'o' 'n' 'a'] ['l']
# ['t' 'r' 'u' 'c' 't' 'i' 'o' 'n' 'a' 'l'] [' ']
# ['r' 'u' 'c' 't' 'i' 'o' 'n' 'a' 'l' ' '] ['l']
# ['u' 'c' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'l'] ['e']
# ['c' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'l' 'e'] ['a']
# ['t' 'i' 'o' 'n' 'a' 'l' ' ' 'l' 'e' 'a'] ['r']
# ['i' 'o' 'n' 'a' 'l' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['o' 'n' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['n' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] [' ']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' '] ['o']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o'] ['p']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p'] ['p']
# ['a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p'] ['o']
# ['r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o'] ['r']
# ['n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r'] ['t']
# ['i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't'] ['u']
# ['n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u'] ['n']
# ['g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n'] ['i']
# [' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i'] ['t']
# ['o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't'] ['i']
# ['p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i'] ['e']
# ['p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e'] ['s']
# ['o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's'] [' ']
# ['r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's' ' '] ['i']
# ['t' 'u' 'n' 'i' 't' 'i' 'e' 's' ' ' 'i'] ['n']
# ['u' 'n' 'i' 't' 'i' 'e' 's' ' ' 'i' 'n'] [' ']
# ['n' 'i' 't' 'i' 'e' 's' ' ' 'i' 'n' ' '] ['t']
# ['i' 't' 'i' 'e' 's' ' ' 'i' 'n' ' ' 't'] ['e']
# ['t' 'i' 'e' 's' ' ' 'i' 'n' ' ' 't' 'e'] ['a']
# ['i' 'e' 's' ' ' 'i' 'n' ' ' 't' 'e' 'a'] ['c']
# ['e' 's' ' ' 'i' 'n' ' ' 't' 'e' 'a' 'c'] ['h']
# ['s' ' ' 'i' 'n' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# [' ' 'i' 'n' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['i' 'n' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] ['s']
# ['n' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's'] ['’']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’'] [' ']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' '] ['w']
# ['e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'w'] ['o']
# ['a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'w' 'o'] ['r']
# ['c' 'h' 'e' 'r' 's' '’' ' ' 'w' 'o' 'r'] ['k']
# ['h' 'e' 'r' 's' '’' ' ' 'w' 'o' 'r' 'k'] ['g']
# ['e' 'r' 's' '’' ' ' 'w' 'o' 'r' 'k' 'g'] ['r']
# ['r' 's' '’' ' ' 'w' 'o' 'r' 'k' 'g' 'r'] ['o']
# ['s' '’' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o'] ['u']
# ['’' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u'] ['p']
# [' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p'] [' ']
# ['w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' '] ['c']
# ['o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'c'] ['o']
# ['r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'c' 'o'] ['n']
# ['k' 'g' 'r' 'o' 'u' 'p' ' ' 'c' 'o' 'n'] ['v']
# ['g' 'r' 'o' 'u' 'p' ' ' 'c' 'o' 'n' 'v'] ['e']
# ['r' 'o' 'u' 'p' ' ' 'c' 'o' 'n' 'v' 'e'] ['r']
# ['o' 'u' 'p' ' ' 'c' 'o' 'n' 'v' 'e' 'r'] ['s']
# ['u' 'p' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's'] ['a']
# ['p' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a'] ['t']
# [' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't'] ['i']
# ['c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i'] ['o']
# ['o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o'] ['n']
# ['n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n'] ['s']
# ['v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's'] ['Ⓐ']
# ['e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's' 'Ⓐ'] ['m']
# ['r' 's' 'a' 't' 'i' 'o' 'n' 's' 'Ⓐ' 'm'] ['a']
# ['s' 'a' 't' 'i' 'o' 'n' 's' 'Ⓐ' 'm' 'a'] ['n']
# ['a' 't' 'i' 'o' 'n' 's' 'Ⓐ' 'm' 'a' 'n'] ['y']
# ['t' 'i' 'o' 'n' 's' 'Ⓐ' 'm' 'a' 'n' 'y'] [' ']
# ['i' 'o' 'n' 's' 'Ⓐ' 'm' 'a' 'n' 'y' ' '] ['s']
# ['o' 'n' 's' 'Ⓐ' 'm' 'a' 'n' 'y' ' ' 's'] ['c']
# ['n' 's' 'Ⓐ' 'm' 'a' 'n' 'y' ' ' 's' 'c'] ['h']
# ['s' 'Ⓐ' 'm' 'a' 'n' 'y' ' ' 's' 'c' 'h'] ['o']
# ['Ⓐ' 'm' 'a' 'n' 'y' ' ' 's' 'c' 'h' 'o'] ['o']
# ['m' 'a' 'n' 'y' ' ' 's' 'c' 'h' 'o' 'o'] ['l']
# ['a' 'n' 'y' ' ' 's' 'c' 'h' 'o' 'o' 'l'] ['-']
# ['n' 'y' ' ' 's' 'c' 'h' 'o' 'o' 'l' '-'] ['i']
# ['y' ' ' 's' 'c' 'h' 'o' 'o' 'l' '-' 'i'] ['m']
# [' ' 's' 'c' 'h' 'o' 'o' 'l' '-' 'i' 'm'] ['p']
# ['s' 'c' 'h' 'o' 'o' 'l' '-' 'i' 'm' 'p'] ['r']
# ['c' 'h' 'o' 'o' 'l' '-' 'i' 'm' 'p' 'r'] ['o']
# ['h' 'o' 'o' 'l' '-' 'i' 'm' 'p' 'r' 'o'] ['v']
# ['o' 'o' 'l' '-' 'i' 'm' 'p' 'r' 'o' 'v'] ['e']
# ['o' 'l' '-' 'i' 'm' 'p' 'r' 'o' 'v' 'e'] ['m']
# ['l' '-' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm'] ['e']
# ['-' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e'] ['n']
# ['i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n'] ['t']
# ['m' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't'] [' ']
# ['p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't' ' '] ['e']
# ['r' 'o' 'v' 'e' 'm' 'e' 'n' 't' ' ' 'e'] ['f']
# ['o' 'v' 'e' 'm' 'e' 'n' 't' ' ' 'e' 'f'] ['f']
# ['v' 'e' 'm' 'e' 'n' 't' ' ' 'e' 'f' 'f'] ['o']
# ['e' 'm' 'e' 'n' 't' ' ' 'e' 'f' 'f' 'o'] ['r']
# ['m' 'e' 'n' 't' ' ' 'e' 'f' 'f' 'o' 'r'] ['t']
# ['e' 'n' 't' ' ' 'e' 'f' 'f' 'o' 'r' 't'] ['s']
# ['n' 't' ' ' 'e' 'f' 'f' 'o' 'r' 't' 's'] [' ']
# ['t' ' ' 'e' 'f' 'f' 'o' 'r' 't' 's' ' '] ['i']
# [' ' 'e' 'f' 'f' 'o' 'r' 't' 's' ' ' 'i'] ['n']
# ['e' 'f' 'f' 'o' 'r' 't' 's' ' ' 'i' 'n'] ['c']
# ['f' 'f' 'o' 'r' 't' 's' ' ' 'i' 'n' 'c'] ['l']
# ['f' 'o' 'r' 't' 's' ' ' 'i' 'n' 'c' 'l'] ['u']
# ['o' 'r' 't' 's' ' ' 'i' 'n' 'c' 'l' 'u'] ['d']
# ['r' 't' 's' ' ' 'i' 'n' 'c' 'l' 'u' 'd'] ['e']
# ['t' 's' ' ' 'i' 'n' 'c' 'l' 'u' 'd' 'e'] [' ']
# ['s' ' ' 'i' 'n' 'c' 'l' 'u' 'd' 'e' ' '] ['t']
# [' ' 'i' 'n' 'c' 'l' 'u' 'd' 'e' ' ' 't'] ['i']
# ['i' 'n' 'c' 'l' 'u' 'd' 'e' ' ' 't' 'i'] ['m']
# ['n' 'c' 'l' 'u' 'd' 'e' ' ' 't' 'i' 'm'] ['e']
# ['c' 'l' 'u' 'd' 'e' ' ' 't' 'i' 'm' 'e'] [' ']
# ['l' 'u' 'd' 'e' ' ' 't' 'i' 'm' 'e' ' '] ['f']
# ['u' 'd' 'e' ' ' 't' 'i' 'm' 'e' ' ' 'f'] ['o']
# ['d' 'e' ' ' 't' 'i' 'm' 'e' ' ' 'f' 'o'] ['r']
# ['e' ' ' 't' 'i' 'm' 'e' ' ' 'f' 'o' 'r'] [' ']
# [' ' 't' 'i' 'm' 'e' ' ' 'f' 'o' 'r' ' '] ['t']
# ['t' 'i' 'm' 'e' ' ' 'f' 'o' 'r' ' ' 't'] ['e']
# ['i' 'm' 'e' ' ' 'f' 'o' 'r' ' ' 't' 'e'] ['a']
# ['m' 'e' ' ' 'f' 'o' 'r' ' ' 't' 'e' 'a'] ['c']
# ['e' ' ' 'f' 'o' 'r' ' ' 't' 'e' 'a' 'c'] ['h']
# [' ' 'f' 'o' 'r' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# ['f' 'o' 'r' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['o' 'r' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] [' ']
# ['r' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' '] ['c']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'c'] ['o']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'c' 'o'] ['l']
# ['e' 'a' 'c' 'h' 'e' 'r' ' ' 'c' 'o' 'l'] ['l']
# ['a' 'c' 'h' 'e' 'r' ' ' 'c' 'o' 'l' 'l'] ['a']
# ['c' 'h' 'e' 'r' ' ' 'c' 'o' 'l' 'l' 'a'] ['b']
# ['h' 'e' 'r' ' ' 'c' 'o' 'l' 'l' 'a' 'b'] ['o']
# ['e' 'r' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o'] ['r']
# ['r' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r'] ['a']
# [' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a'] ['t']
# ['c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't'] ['i']
# ['o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i'] ['o']
# ['l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o'] ['n']
# ['l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n'] [',']
# ['a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n' ','] [' ']
# ['b' 'o' 'r' 'a' 't' 'i' 'o' 'n' ',' ' '] ['w']
# ['o' 'r' 'a' 't' 'i' 'o' 'n' ',' ' ' 'w'] ['i']
# ['r' 'a' 't' 'i' 'o' 'n' ',' ' ' 'w' 'i'] ['t']
# ['a' 't' 'i' 'o' 'n' ',' ' ' 'w' 'i' 't'] ['h']
# ['t' 'i' 'o' 'n' ',' ' ' 'w' 'i' 't' 'h'] [' ']
# ['i' 'o' 'n' ',' ' ' 'w' 'i' 't' 'h' ' '] ['t']
# ['o' 'n' ',' ' ' 'w' 'i' 't' 'h' ' ' 't'] ['h']
# ['n' ',' ' ' 'w' 'i' 't' 'h' ' ' 't' 'h'] ['e']
# [',' ' ' 'w' 'i' 't' 'h' ' ' 't' 'h' 'e'] [' ']
# [' ' 'w' 'i' 't' 'h' ' ' 't' 'h' 'e' ' '] ['a']
# ['w' 'i' 't' 'h' ' ' 't' 'h' 'e' ' ' 'a'] ['s']
# ['i' 't' 'h' ' ' 't' 'h' 'e' ' ' 'a' 's'] ['s']
# ['t' 'h' ' ' 't' 'h' 'e' ' ' 'a' 's' 's'] ['u']
# ['h' ' ' 't' 'h' 'e' ' ' 'a' 's' 's' 'u'] ['m']
# [' ' 't' 'h' 'e' ' ' 'a' 's' 's' 'u' 'm'] ['p']
# ['t' 'h' 'e' ' ' 'a' 's' 's' 'u' 'm' 'p'] ['t']
# ['h' 'e' ' ' 'a' 's' 's' 'u' 'm' 'p' 't'] ['i']
# ['e' ' ' 'a' 's' 's' 'u' 'm' 'p' 't' 'i'] ['o']
# [' ' 'a' 's' 's' 'u' 'm' 'p' 't' 'i' 'o'] ['n']
# ['a' 's' 's' 'u' 'm' 'p' 't' 'i' 'o' 'n'] [' ']
# ['s' 's' 'u' 'm' 'p' 't' 'i' 'o' 'n' ' '] ['t']
# ['s' 'u' 'm' 'p' 't' 'i' 'o' 'n' ' ' 't'] ['h']
# ['u' 'm' 'p' 't' 'i' 'o' 'n' ' ' 't' 'h'] ['a']
# ['m' 'p' 't' 'i' 'o' 'n' ' ' 't' 'h' 'a'] ['t']
# ['p' 't' 'i' 'o' 'n' ' ' 't' 'h' 'a' 't'] [' ']
# ['t' 'i' 'o' 'n' ' ' 't' 'h' 'a' 't' ' '] ['t']
# ['i' 'o' 'n' ' ' 't' 'h' 'a' 't' ' ' 't'] ['e']
# ['o' 'n' ' ' 't' 'h' 'a' 't' ' ' 't' 'e'] ['a']
# ['n' ' ' 't' 'h' 'a' 't' ' ' 't' 'e' 'a'] ['c']
# [' ' 't' 'h' 'a' 't' ' ' 't' 'e' 'a' 'c'] ['h']
# ['t' 'h' 'a' 't' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# ['h' 'a' 't' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['a' 't' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] ['s']
# ['t' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's'] ['’']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’'] [' ']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' '] ['c']
# ['e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'c'] ['o']
# ['a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'c' 'o'] ['l']
# ['c' 'h' 'e' 'r' 's' '’' ' ' 'c' 'o' 'l'] ['l']
# ['h' 'e' 'r' 's' '’' ' ' 'c' 'o' 'l' 'l'] ['e']
# ['e' 'r' 's' '’' ' ' 'c' 'o' 'l' 'l' 'e'] ['c']
# ['r' 's' '’' ' ' 'c' 'o' 'l' 'l' 'e' 'c'] ['t']
# ['s' '’' ' ' 'c' 'o' 'l' 'l' 'e' 'c' 't'] ['i']
# ['’' ' ' 'c' 'o' 'l' 'l' 'e' 'c' 't' 'i'] ['v']
# [' ' 'c' 'o' 'l' 'l' 'e' 'c' 't' 'i' 'v'] ['e']
# ['c' 'o' 'l' 'l' 'e' 'c' 't' 'i' 'v' 'e'] [' ']
# ['o' 'l' 'l' 'e' 'c' 't' 'i' 'v' 'e' ' '] ['w']
# ['l' 'l' 'e' 'c' 't' 'i' 'v' 'e' ' ' 'w'] ['o']
# ['l' 'e' 'c' 't' 'i' 'v' 'e' ' ' 'w' 'o'] ['r']
# ['e' 'c' 't' 'i' 'v' 'e' ' ' 'w' 'o' 'r'] ['k']
# ['c' 't' 'i' 'v' 'e' ' ' 'w' 'o' 'r' 'k'] [' ']
# ['t' 'i' 'v' 'e' ' ' 'w' 'o' 'r' 'k' ' '] ['s']
# ['i' 'v' 'e' ' ' 'w' 'o' 'r' 'k' ' ' 's'] ['u']
# ['v' 'e' ' ' 'w' 'o' 'r' 'k' ' ' 's' 'u'] ['p']
# ['e' ' ' 'w' 'o' 'r' 'k' ' ' 's' 'u' 'p'] ['p']
# [' ' 'w' 'o' 'r' 'k' ' ' 's' 'u' 'p' 'p'] ['o']
# ['w' 'o' 'r' 'k' ' ' 's' 'u' 'p' 'p' 'o'] ['r']
# ['o' 'r' 'k' ' ' 's' 'u' 'p' 'p' 'o' 'r'] ['t']
# ['r' 'k' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't'] ['s']
# ['k' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't' 's'] [' ']
# [' ' 's' 'u' 'p' 'p' 'o' 'r' 't' 's' ' '] ['i']
# ['s' 'u' 'p' 'p' 'o' 'r' 't' 's' ' ' 'i'] ['n']
# ['u' 'p' 'p' 'o' 'r' 't' 's' ' ' 'i' 'n'] ['s']
# ['p' 'p' 'o' 'r' 't' 's' ' ' 'i' 'n' 's'] ['t']
# ['p' 'o' 'r' 't' 's' ' ' 'i' 'n' 's' 't'] ['r']
# ['o' 'r' 't' 's' ' ' 'i' 'n' 's' 't' 'r'] ['u']
# ['r' 't' 's' ' ' 'i' 'n' 's' 't' 'r' 'u'] ['c']
# ['t' 's' ' ' 'i' 'n' 's' 't' 'r' 'u' 'c'] ['t']
# ['s' ' ' 'i' 'n' 's' 't' 'r' 'u' 'c' 't'] ['i']
# [' ' 'i' 'n' 's' 't' 'r' 'u' 'c' 't' 'i'] ['o']
# ['i' 'n' 's' 't' 'r' 'u' 'c' 't' 'i' 'o'] ['n']
# ['n' 's' 't' 'r' 'u' 'c' 't' 'i' 'o' 'n'] ['a']
# ['s' 't' 'r' 'u' 'c' 't' 'i' 'o' 'n' 'a'] ['l']
# ['t' 'r' 'u' 'c' 't' 'i' 'o' 'n' 'a' 'l'] [' ']
# ['r' 'u' 'c' 't' 'i' 'o' 'n' 'a' 'l' ' '] ['i']
# ['u' 'c' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'i'] ['m']
# ['c' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'i' 'm'] ['p']
# ['t' 'i' 'o' 'n' 'a' 'l' ' ' 'i' 'm' 'p'] ['r']
# ['i' 'o' 'n' 'a' 'l' ' ' 'i' 'm' 'p' 'r'] ['o']
# ['o' 'n' 'a' 'l' ' ' 'i' 'm' 'p' 'r' 'o'] ['v']
# ['n' 'a' 'l' ' ' 'i' 'm' 'p' 'r' 'o' 'v'] ['e']
# ['a' 'l' ' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e'] ['m']
# ['l' ' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm'] ['e']
# [' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e'] ['n']
# ['i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n'] ['t']
# ['m' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't'] ['.']
# ['p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't' '.'] [' ']
# ['r' 'o' 'v' 'e' 'm' 'e' 'n' 't' '.' ' '] ['h']
# ['o' 'v' 'e' 'm' 'e' 'n' 't' '.' ' ' 'h'] ['o']
# ['v' 'e' 'm' 'e' 'n' 't' '.' ' ' 'h' 'o'] ['w']
# ['e' 'm' 'e' 'n' 't' '.' ' ' 'h' 'o' 'w'] ['e']
# ['m' 'e' 'n' 't' '.' ' ' 'h' 'o' 'w' 'e'] ['v']
# ['e' 'n' 't' '.' ' ' 'h' 'o' 'w' 'e' 'v'] ['e']
# ['n' 't' '.' ' ' 'h' 'o' 'w' 'e' 'v' 'e'] ['r']
# ['t' '.' ' ' 'h' 'o' 'w' 'e' 'v' 'e' 'r'] [',']
# ['.' ' ' 'h' 'o' 'w' 'e' 'v' 'e' 'r' ','] [' ']
# [' ' 'h' 'o' 'w' 'e' 'v' 'e' 'r' ',' ' '] ['n']
# ['h' 'o' 'w' 'e' 'v' 'e' 'r' ',' ' ' 'n'] ['o']
# ['o' 'w' 'e' 'v' 'e' 'r' ',' ' ' 'n' 'o'] ['t']
# ['w' 'e' 'v' 'e' 'r' ',' ' ' 'n' 'o' 't'] [' ']
# ['e' 'v' 'e' 'r' ',' ' ' 'n' 'o' 't' ' '] ['a']
# ['v' 'e' 'r' ',' ' ' 'n' 'o' 't' ' ' 'a'] ['l']
# ['e' 'r' ',' ' ' 'n' 'o' 't' ' ' 'a' 'l'] ['l']
# ['r' ',' ' ' 'n' 'o' 't' ' ' 'a' 'l' 'l'] [' ']
# [',' ' ' 'n' 'o' 't' ' ' 'a' 'l' 'l' ' '] ['c']
# [' ' 'n' 'o' 't' ' ' 'a' 'l' 'l' ' ' 'c'] ['o']
# ['n' 'o' 't' ' ' 'a' 'l' 'l' ' ' 'c' 'o'] ['l']
# ['o' 't' ' ' 'a' 'l' 'l' ' ' 'c' 'o' 'l'] ['l']
# ['t' ' ' 'a' 'l' 'l' ' ' 'c' 'o' 'l' 'l'] ['a']
# [' ' 'a' 'l' 'l' ' ' 'c' 'o' 'l' 'l' 'a'] ['b']
# ['a' 'l' 'l' ' ' 'c' 'o' 'l' 'l' 'a' 'b'] ['o']
# ['l' 'l' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o'] ['r']
# ['l' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r'] ['a']
# [' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a'] ['t']
# ['c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't'] ['i']
# ['o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i'] ['o']
# ['l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o'] ['n']
# ['l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n'] [' ']
# ['a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n' ' '] ['e']
# ['b' 'o' 'r' 'a' 't' 'i' 'o' 'n' ' ' 'e'] ['q']
# ['o' 'r' 'a' 't' 'i' 'o' 'n' ' ' 'e' 'q'] ['u']
# ['r' 'a' 't' 'i' 'o' 'n' ' ' 'e' 'q' 'u'] ['a']
# ['a' 't' 'i' 'o' 'n' ' ' 'e' 'q' 'u' 'a'] ['l']
# ['t' 'i' 'o' 'n' ' ' 'e' 'q' 'u' 'a' 'l'] ['l']
# ['i' 'o' 'n' ' ' 'e' 'q' 'u' 'a' 'l' 'l'] ['y']
# ['o' 'n' ' ' 'e' 'q' 'u' 'a' 'l' 'l' 'y'] [' ']
# ['n' ' ' 'e' 'q' 'u' 'a' 'l' 'l' 'y' ' '] ['s']
# [' ' 'e' 'q' 'u' 'a' 'l' 'l' 'y' ' ' 's'] ['u']
# ['e' 'q' 'u' 'a' 'l' 'l' 'y' ' ' 's' 'u'] ['p']
# ['q' 'u' 'a' 'l' 'l' 'y' ' ' 's' 'u' 'p'] ['p']
# ['u' 'a' 'l' 'l' 'y' ' ' 's' 'u' 'p' 'p'] ['o']
# ['a' 'l' 'l' 'y' ' ' 's' 'u' 'p' 'p' 'o'] ['r']
# ['l' 'l' 'y' ' ' 's' 'u' 'p' 'p' 'o' 'r'] ['t']
# ['l' 'y' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't'] ['s']
# ['y' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't' 's'] [' ']
# [' ' 's' 'u' 'p' 'p' 'o' 'r' 't' 's' ' '] ['l']
# ['s' 'u' 'p' 'p' 'o' 'r' 't' 's' ' ' 'l'] ['e']
# ['u' 'p' 'p' 'o' 'r' 't' 's' ' ' 'l' 'e'] ['a']
# ['p' 'p' 'o' 'r' 't' 's' ' ' 'l' 'e' 'a'] ['r']
# ['p' 'o' 'r' 't' 's' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['o' 'r' 't' 's' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['r' 't' 's' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['t' 's' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['s' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] [' ']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' '] ['t']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 't'] ['h']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 't' 'h'] ['a']
# ['a' 'r' 'n' 'i' 'n' 'g' ' ' 't' 'h' 'a'] ['t']
# ['r' 'n' 'i' 'n' 'g' ' ' 't' 'h' 'a' 't'] [' ']
# ['n' 'i' 'n' 'g' ' ' 't' 'h' 'a' 't' ' '] ['w']
# ['i' 'n' 'g' ' ' 't' 'h' 'a' 't' ' ' 'w'] ['o']
# ['n' 'g' ' ' 't' 'h' 'a' 't' ' ' 'w' 'o'] ['u']
# ['g' ' ' 't' 'h' 'a' 't' ' ' 'w' 'o' 'u'] ['l']
# [' ' 't' 'h' 'a' 't' ' ' 'w' 'o' 'u' 'l'] ['d']
# ['t' 'h' 'a' 't' ' ' 'w' 'o' 'u' 'l' 'd'] [' ']
# ['h' 'a' 't' ' ' 'w' 'o' 'u' 'l' 'd' ' '] ['s']
# ['a' 't' ' ' 'w' 'o' 'u' 'l' 'd' ' ' 's'] ['u']
# ['t' ' ' 'w' 'o' 'u' 'l' 'd' ' ' 's' 'u'] ['p']
# [' ' 'w' 'o' 'u' 'l' 'd' ' ' 's' 'u' 'p'] ['p']
# ['w' 'o' 'u' 'l' 'd' ' ' 's' 'u' 'p' 'p'] ['o']
# ['o' 'u' 'l' 'd' ' ' 's' 'u' 'p' 'p' 'o'] ['r']
# ['u' 'l' 'd' ' ' 's' 'u' 'p' 'p' 'o' 'r'] ['t']
# ['l' 'd' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't'] [' ']
# ['d' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't' ' '] ['i']
# [' ' 's' 'u' 'p' 'p' 'o' 'r' 't' ' ' 'i'] ['m']
# ['s' 'u' 'p' 'p' 'o' 'r' 't' ' ' 'i' 'm'] ['p']
# ['u' 'p' 'p' 'o' 'r' 't' ' ' 'i' 'm' 'p'] ['r']
# ['p' 'p' 'o' 'r' 't' ' ' 'i' 'm' 'p' 'r'] ['o']
# ['p' 'o' 'r' 't' ' ' 'i' 'm' 'p' 'r' 'o'] ['v']
# ['o' 'r' 't' ' ' 'i' 'm' 'p' 'r' 'o' 'v'] ['e']
# ['r' 't' ' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e'] ['m']
# ['t' ' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm'] ['e']
# [' ' 'i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e'] ['n']
# ['i' 'm' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n'] ['t']
# ['m' 'p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't'] ['.']
# ['p' 'r' 'o' 'v' 'e' 'm' 'e' 'n' 't' '.'] [' ']
# ['r' 'o' 'v' 'e' 'm' 'e' 'n' 't' '.' ' '] ['a']
# ['o' 'v' 'e' 'm' 'e' 'n' 't' '.' ' ' 'a'] ['s']
# ['v' 'e' 'm' 'e' 'n' 't' '.' ' ' 'a' 's'] [' ']
# ['e' 'm' 'e' 'n' 't' '.' ' ' 'a' 's' ' '] ['a']
# ['m' 'e' 'n' 't' '.' ' ' 'a' 's' ' ' 'a'] [' ']
# ['e' 'n' 't' '.' ' ' 'a' 's' ' ' 'a' ' '] ['p']
# ['n' 't' '.' ' ' 'a' 's' ' ' 'a' ' ' 'p'] ['a']
# ['t' '.' ' ' 'a' 's' ' ' 'a' ' ' 'p' 'a'] ['r']
# ['.' ' ' 'a' 's' ' ' 'a' ' ' 'p' 'a' 'r'] ['t']
# [' ' 'a' 's' ' ' 'a' ' ' 'p' 'a' 'r' 't'] [' ']
# ['a' 's' ' ' 'a' ' ' 'p' 'a' 'r' 't' ' '] ['o']
# ['s' ' ' 'a' ' ' 'p' 'a' 'r' 't' ' ' 'o'] ['f']
# [' ' 'a' ' ' 'p' 'a' 'r' 't' ' ' 'o' 'f'] [' ']
# ['a' ' ' 'p' 'a' 'r' 't' ' ' 'o' 'f' ' '] ['a']
# [' ' 'p' 'a' 'r' 't' ' ' 'o' 'f' ' ' 'a'] [' ']
# ['p' 'a' 'r' 't' ' ' 'o' 'f' ' ' 'a' ' '] ['5']
# ['a' 'r' 't' ' ' 'o' 'f' ' ' 'a' ' ' '5'] ['-']
# ['r' 't' ' ' 'o' 'f' ' ' 'a' ' ' '5' '-'] ['y']
# ['t' ' ' 'o' 'f' ' ' 'a' ' ' '5' '-' 'y'] ['e']
# [' ' 'o' 'f' ' ' 'a' ' ' '5' '-' 'y' 'e'] ['a']
# ['o' 'f' ' ' 'a' ' ' '5' '-' 'y' 'e' 'a'] ['r']
# ['f' ' ' 'a' ' ' '5' '-' 'y' 'e' 'a' 'r'] [' ']
# [' ' 'a' ' ' '5' '-' 'y' 'e' 'a' 'r' ' '] ['s']
# ['a' ' ' '5' '-' 'y' 'e' 'a' 'r' ' ' 's'] ['t']
# [' ' '5' '-' 'y' 'e' 'a' 'r' ' ' 's' 't'] ['u']
# ['5' '-' 'y' 'e' 'a' 'r' ' ' 's' 't' 'u'] ['d']
# ['-' 'y' 'e' 'a' 'r' ' ' 's' 't' 'u' 'd'] ['y']
# ['y' 'e' 'a' 'r' ' ' 's' 't' 'u' 'd' 'y'] [' ']
# ['e' 'a' 'r' ' ' 's' 't' 'u' 'd' 'y' ' '] ['i']
# ['a' 'r' ' ' 's' 't' 'u' 'd' 'y' ' ' 'i'] ['n']
# ['r' ' ' 's' 't' 'u' 'd' 'y' ' ' 'i' 'n'] [' ']
# [' ' 's' 't' 'u' 'd' 'y' ' ' 'i' 'n' ' '] ['t']
# ['s' 't' 'u' 'd' 'y' ' ' 'i' 'n' ' ' 't'] ['w']
# ['t' 'u' 'd' 'y' ' ' 'i' 'n' ' ' 't' 'w'] ['o']
# ['u' 'd' 'y' ' ' 'i' 'n' ' ' 't' 'w' 'o'] [' ']
# ['d' 'y' ' ' 'i' 'n' ' ' 't' 'w' 'o' ' '] ['u']
# ['y' ' ' 'i' 'n' ' ' 't' 'w' 'o' ' ' 'u'] ['r']
# [' ' 'i' 'n' ' ' 't' 'w' 'o' ' ' 'u' 'r'] ['b']
# ['i' 'n' ' ' 't' 'w' 'o' ' ' 'u' 'r' 'b'] ['a']
# ['n' ' ' 't' 'w' 'o' ' ' 'u' 'r' 'b' 'a'] ['n']
# [' ' 't' 'w' 'o' ' ' 'u' 'r' 'b' 'a' 'n'] [' ']
# ['t' 'w' 'o' ' ' 'u' 'r' 'b' 'a' 'n' ' '] ['s']
# ['w' 'o' ' ' 'u' 'r' 'b' 'a' 'n' ' ' 's'] ['c']
# ['o' ' ' 'u' 'r' 'b' 'a' 'n' ' ' 's' 'c'] ['h']
# [' ' 'u' 'r' 'b' 'a' 'n' ' ' 's' 'c' 'h'] ['o']
# ['u' 'r' 'b' 'a' 'n' ' ' 's' 'c' 'h' 'o'] ['o']
# ['r' 'b' 'a' 'n' ' ' 's' 'c' 'h' 'o' 'o'] ['l']
# ['b' 'a' 'n' ' ' 's' 'c' 'h' 'o' 'o' 'l'] [' ']
# ['a' 'n' ' ' 's' 'c' 'h' 'o' 'o' 'l' ' '] ['d']
# ['n' ' ' 's' 'c' 'h' 'o' 'o' 'l' ' ' 'd'] ['i']
# [' ' 's' 'c' 'h' 'o' 'o' 'l' ' ' 'd' 'i'] ['s']
# ['s' 'c' 'h' 'o' 'o' 'l' ' ' 'd' 'i' 's'] ['t']
# ['c' 'h' 'o' 'o' 'l' ' ' 'd' 'i' 's' 't'] ['r']
# ['h' 'o' 'o' 'l' ' ' 'd' 'i' 's' 't' 'r'] ['i']
# ['o' 'o' 'l' ' ' 'd' 'i' 's' 't' 'r' 'i'] ['c']
# ['o' 'l' ' ' 'd' 'i' 's' 't' 'r' 'i' 'c'] ['t']
# ['l' ' ' 'd' 'i' 's' 't' 'r' 'i' 'c' 't'] ['s']
# [' ' 'd' 'i' 's' 't' 'r' 'i' 'c' 't' 's'] [',']
# ['d' 'i' 's' 't' 'r' 'i' 'c' 't' 's' ','] [' ']
# ['i' 's' 't' 'r' 'i' 'c' 't' 's' ',' ' '] ['w']
# ['s' 't' 'r' 'i' 'c' 't' 's' ',' ' ' 'w'] ['e']
# ['t' 'r' 'i' 'c' 't' 's' ',' ' ' 'w' 'e'] [' ']
# ['r' 'i' 'c' 't' 's' ',' ' ' 'w' 'e' ' '] ['c']
# ['i' 'c' 't' 's' ',' ' ' 'w' 'e' ' ' 'c'] ['o']
# ['c' 't' 's' ',' ' ' 'w' 'e' ' ' 'c' 'o'] ['l']
# ['t' 's' ',' ' ' 'w' 'e' ' ' 'c' 'o' 'l'] ['l']
# ['s' ',' ' ' 'w' 'e' ' ' 'c' 'o' 'l' 'l'] ['e']
# [',' ' ' 'w' 'e' ' ' 'c' 'o' 'l' 'l' 'e'] ['c']
# [' ' 'w' 'e' ' ' 'c' 'o' 'l' 'l' 'e' 'c'] ['t']
# ['w' 'e' ' ' 'c' 'o' 'l' 'l' 'e' 'c' 't'] ['e']
# ['e' ' ' 'c' 'o' 'l' 'l' 'e' 'c' 't' 'e'] ['d']
# [' ' 'c' 'o' 'l' 'l' 'e' 'c' 't' 'e' 'd'] [' ']
# ['c' 'o' 'l' 'l' 'e' 'c' 't' 'e' 'd' ' '] ['v']
# ['o' 'l' 'l' 'e' 'c' 't' 'e' 'd' ' ' 'v'] ['i']
# ['l' 'l' 'e' 'c' 't' 'e' 'd' ' ' 'v' 'i'] ['d']
# ['l' 'e' 'c' 't' 'e' 'd' ' ' 'v' 'i' 'd'] ['e']
# ['e' 'c' 't' 'e' 'd' ' ' 'v' 'i' 'd' 'e'] ['o']
# ['c' 't' 'e' 'd' ' ' 'v' 'i' 'd' 'e' 'o'] [' ']
# ['t' 'e' 'd' ' ' 'v' 'i' 'd' 'e' 'o' ' '] ['r']
# ['e' 'd' ' ' 'v' 'i' 'd' 'e' 'o' ' ' 'r'] ['e']
# ['d' ' ' 'v' 'i' 'd' 'e' 'o' ' ' 'r' 'e'] ['c']
# [' ' 'v' 'i' 'd' 'e' 'o' ' ' 'r' 'e' 'c'] ['o']
# ['v' 'i' 'd' 'e' 'o' ' ' 'r' 'e' 'c' 'o'] ['r']
# ['i' 'd' 'e' 'o' ' ' 'r' 'e' 'c' 'o' 'r'] ['d']
# ['d' 'e' 'o' ' ' 'r' 'e' 'c' 'o' 'r' 'd'] ['s']
# ['e' 'o' ' ' 'r' 'e' 'c' 'o' 'r' 'd' 's'] [' ']
# ['o' ' ' 'r' 'e' 'c' 'o' 'r' 'd' 's' ' '] ['o']
# [' ' 'r' 'e' 'c' 'o' 'r' 'd' 's' ' ' 'o'] ['f']
# ['r' 'e' 'c' 'o' 'r' 'd' 's' ' ' 'o' 'f'] [' ']
# ['e' 'c' 'o' 'r' 'd' 's' ' ' 'o' 'f' ' '] ['m']
# ['c' 'o' 'r' 'd' 's' ' ' 'o' 'f' ' ' 'm'] ['o']
# ['o' 'r' 'd' 's' ' ' 'o' 'f' ' ' 'm' 'o'] ['r']
# ['r' 'd' 's' ' ' 'o' 'f' ' ' 'm' 'o' 'r'] ['e']
# ['d' 's' ' ' 'o' 'f' ' ' 'm' 'o' 'r' 'e'] [' ']
# ['s' ' ' 'o' 'f' ' ' 'm' 'o' 'r' 'e' ' '] ['t']
# [' ' 'o' 'f' ' ' 'm' 'o' 'r' 'e' ' ' 't'] ['h']
# ['o' 'f' ' ' 'm' 'o' 'r' 'e' ' ' 't' 'h'] ['a']
# ['f' ' ' 'm' 'o' 'r' 'e' ' ' 't' 'h' 'a'] ['n']
# [' ' 'm' 'o' 'r' 'e' ' ' 't' 'h' 'a' 'n'] [' ']
# ['m' 'o' 'r' 'e' ' ' 't' 'h' 'a' 'n' ' '] ['1']
# ['o' 'r' 'e' ' ' 't' 'h' 'a' 'n' ' ' '1'] ['0']
# ['r' 'e' ' ' 't' 'h' 'a' 'n' ' ' '1' '0'] ['0']
# ['e' ' ' 't' 'h' 'a' 'n' ' ' '1' '0' '0'] [' ']
# [' ' 't' 'h' 'a' 'n' ' ' '1' '0' '0' ' '] ['m']
# ['t' 'h' 'a' 'n' ' ' '1' '0' '0' ' ' 'm'] ['a']
# ['h' 'a' 'n' ' ' '1' '0' '0' ' ' 'm' 'a'] ['t']
# ['a' 'n' ' ' '1' '0' '0' ' ' 'm' 'a' 't'] ['h']
# ['n' ' ' '1' '0' '0' ' ' 'm' 'a' 't' 'h'] ['e']
# [' ' '1' '0' '0' ' ' 'm' 'a' 't' 'h' 'e'] ['m']
# ['1' '0' '0' ' ' 'm' 'a' 't' 'h' 'e' 'm'] ['a']
# ['0' '0' ' ' 'm' 'a' 't' 'h' 'e' 'm' 'a'] ['t']
# ['0' ' ' 'm' 'a' 't' 'h' 'e' 'm' 'a' 't'] ['i']
# [' ' 'm' 'a' 't' 'h' 'e' 'm' 'a' 't' 'i'] ['c']
# ['m' 'a' 't' 'h' 'e' 'm' 'a' 't' 'i' 'c'] ['s']
# ['a' 't' 'h' 'e' 'm' 'a' 't' 'i' 'c' 's'] [' ']
# ['t' 'h' 'e' 'm' 'a' 't' 'i' 'c' 's' ' '] ['t']
# ['h' 'e' 'm' 'a' 't' 'i' 'c' 's' ' ' 't'] ['e']
# ['e' 'm' 'a' 't' 'i' 'c' 's' ' ' 't' 'e'] ['a']
# ['m' 'a' 't' 'i' 'c' 's' ' ' 't' 'e' 'a'] ['c']
# ['a' 't' 'i' 'c' 's' ' ' 't' 'e' 'a' 'c'] ['h']
# ['t' 'i' 'c' 's' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# ['i' 'c' 's' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['c' 's' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] [' ']
# ['s' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' '] ['w']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'w'] ['o']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'w' 'o'] ['r']
# ['e' 'a' 'c' 'h' 'e' 'r' ' ' 'w' 'o' 'r'] ['k']
# ['a' 'c' 'h' 'e' 'r' ' ' 'w' 'o' 'r' 'k'] ['g']
# ['c' 'h' 'e' 'r' ' ' 'w' 'o' 'r' 'k' 'g'] ['r']
# ['h' 'e' 'r' ' ' 'w' 'o' 'r' 'k' 'g' 'r'] ['o']
# ['e' 'r' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o'] ['u']
# ['r' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u'] ['p']
# [' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p'] [' ']
# ['w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' '] ['m']
# ['o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'm'] ['e']
# ['r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'm' 'e'] ['e']
# ['k' 'g' 'r' 'o' 'u' 'p' ' ' 'm' 'e' 'e'] ['t']
# ['g' 'r' 'o' 'u' 'p' ' ' 'm' 'e' 'e' 't'] ['i']
# ['r' 'o' 'u' 'p' ' ' 'm' 'e' 'e' 't' 'i'] ['n']
# ['o' 'u' 'p' ' ' 'm' 'e' 'e' 't' 'i' 'n'] ['g']
# ['u' 'p' ' ' 'm' 'e' 'e' 't' 'i' 'n' 'g'] ['s']
# ['p' ' ' 'm' 'e' 'e' 't' 'i' 'n' 'g' 's'] [' ']
# [' ' 'm' 'e' 'e' 't' 'i' 'n' 'g' 's' ' '] ['i']
# ['m' 'e' 'e' 't' 'i' 'n' 'g' 's' ' ' 'i'] ['n']
# ['e' 'e' 't' 'i' 'n' 'g' 's' ' ' 'i' 'n'] [' ']
# ['e' 't' 'i' 'n' 'g' 's' ' ' 'i' 'n' ' '] ['1']
# ['t' 'i' 'n' 'g' 's' ' ' 'i' 'n' ' ' '1'] ['6']
# ['i' 'n' 'g' 's' ' ' 'i' 'n' ' ' '1' '6'] [' ']
# ['n' 'g' 's' ' ' 'i' 'n' ' ' '1' '6' ' '] ['d']
# ['g' 's' ' ' 'i' 'n' ' ' '1' '6' ' ' 'd'] ['i']
# ['s' ' ' 'i' 'n' ' ' '1' '6' ' ' 'd' 'i'] ['f']
# [' ' 'i' 'n' ' ' '1' '6' ' ' 'd' 'i' 'f'] ['f']
# ['i' 'n' ' ' '1' '6' ' ' 'd' 'i' 'f' 'f'] ['e']
# ['n' ' ' '1' '6' ' ' 'd' 'i' 'f' 'f' 'e'] ['r']
# [' ' '1' '6' ' ' 'd' 'i' 'f' 'f' 'e' 'r'] ['e']
# ['1' '6' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e'] ['n']
# ['6' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n'] ['t']
# [' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't'] [' ']
# ['d' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't' ' '] ['m']
# ['i' 'f' 'f' 'e' 'r' 'e' 'n' 't' ' ' 'm'] ['i']
# ['f' 'f' 'e' 'r' 'e' 'n' 't' ' ' 'm' 'i'] ['d']
# ['f' 'e' 'r' 'e' 'n' 't' ' ' 'm' 'i' 'd'] ['d']
# ['e' 'r' 'e' 'n' 't' ' ' 'm' 'i' 'd' 'd'] ['l']
# ['r' 'e' 'n' 't' ' ' 'm' 'i' 'd' 'd' 'l'] ['e']
# ['e' 'n' 't' ' ' 'm' 'i' 'd' 'd' 'l' 'e'] [' ']
# ['n' 't' ' ' 'm' 'i' 'd' 'd' 'l' 'e' ' '] ['s']
# ['t' ' ' 'm' 'i' 'd' 'd' 'l' 'e' ' ' 's'] ['c']
# [' ' 'm' 'i' 'd' 'd' 'l' 'e' ' ' 's' 'c'] ['h']
# ['m' 'i' 'd' 'd' 'l' 'e' ' ' 's' 'c' 'h'] ['o']
# ['i' 'd' 'd' 'l' 'e' ' ' 's' 'c' 'h' 'o'] ['o']
# ['d' 'd' 'l' 'e' ' ' 's' 'c' 'h' 'o' 'o'] ['l']
# ['d' 'l' 'e' ' ' 's' 'c' 'h' 'o' 'o' 'l'] ['s']
# ['l' 'e' ' ' 's' 'c' 'h' 'o' 'o' 'l' 's'] [',']
# ['e' ' ' 's' 'c' 'h' 'o' 'o' 'l' 's' ','] [' ']
# [' ' 's' 'c' 'h' 'o' 'o' 'l' 's' ',' ' '] ['s']
# ['s' 'c' 'h' 'o' 'o' 'l' 's' ',' ' ' 's'] ['e']
# ['c' 'h' 'o' 'o' 'l' 's' ',' ' ' 's' 'e'] ['l']
# ['h' 'o' 'o' 'l' 's' ',' ' ' 's' 'e' 'l'] ['e']
# ['o' 'o' 'l' 's' ',' ' ' 's' 'e' 'l' 'e'] ['c']
# ['o' 'l' 's' ',' ' ' 's' 'e' 'l' 'e' 'c'] ['t']
# ['l' 's' ',' ' ' 's' 'e' 'l' 'e' 'c' 't'] ['e']
# ['s' ',' ' ' 's' 'e' 'l' 'e' 'c' 't' 'e'] ['d']
# [',' ' ' 's' 'e' 'l' 'e' 'c' 't' 'e' 'd'] [' ']
# [' ' 's' 'e' 'l' 'e' 'c' 't' 'e' 'd' ' '] ['a']
# ['s' 'e' 'l' 'e' 'c' 't' 'e' 'd' ' ' 'a'] ['s']
# ['e' 'l' 'e' 'c' 't' 'e' 'd' ' ' 'a' 's'] [' ']
# ['l' 'e' 'c' 't' 'e' 'd' ' ' 'a' 's' ' '] ['“']
# ['e' 'c' 't' 'e' 'd' ' ' 'a' 's' ' ' '“'] ['b']
# ['c' 't' 'e' 'd' ' ' 'a' 's' ' ' '“' 'b'] ['e']
# ['t' 'e' 'd' ' ' 'a' 's' ' ' '“' 'b' 'e'] ['s']
# ['e' 'd' ' ' 'a' 's' ' ' '“' 'b' 'e' 's'] ['t']
# ['d' ' ' 'a' 's' ' ' '“' 'b' 'e' 's' 't'] [' ']
# [' ' 'a' 's' ' ' '“' 'b' 'e' 's' 't' ' '] ['c']
# ['a' 's' ' ' '“' 'b' 'e' 's' 't' ' ' 'c'] ['a']
# ['s' ' ' '“' 'b' 'e' 's' 't' ' ' 'c' 'a'] ['s']
# [' ' '“' 'b' 'e' 's' 't' ' ' 'c' 'a' 's'] ['e']
# ['“' 'b' 'e' 's' 't' ' ' 'c' 'a' 's' 'e'] ['s']
# ['b' 'e' 's' 't' ' ' 'c' 'a' 's' 'e' 's'] ['”']
# ['e' 's' 't' ' ' 'c' 'a' 's' 'e' 's' '”'] [' ']
# ['s' 't' ' ' 'c' 'a' 's' 'e' 's' '”' ' '] ['o']
# ['t' ' ' 'c' 'a' 's' 'e' 's' '”' ' ' 'o'] ['f']
# [' ' 'c' 'a' 's' 'e' 's' '”' ' ' 'o' 'f'] [' ']
# ['c' 'a' 's' 'e' 's' '”' ' ' 'o' 'f' ' '] ['t']
# ['a' 's' 'e' 's' '”' ' ' 'o' 'f' ' ' 't'] ['e']
# ['s' 'e' 's' '”' ' ' 'o' 'f' ' ' 't' 'e'] ['a']
# ['e' 's' '”' ' ' 'o' 'f' ' ' 't' 'e' 'a'] ['c']
# ['s' '”' ' ' 'o' 'f' ' ' 't' 'e' 'a' 'c'] ['h']
# ['”' ' ' 'o' 'f' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# [' ' 'o' 'f' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['o' 'f' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] [' ']
# ['f' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' '] ['c']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'c'] ['o']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' ' ' 'c' 'o'] ['l']
# ['e' 'a' 'c' 'h' 'e' 'r' ' ' 'c' 'o' 'l'] ['l']
# ['a' 'c' 'h' 'e' 'r' ' ' 'c' 'o' 'l' 'l'] ['a']
# ['c' 'h' 'e' 'r' ' ' 'c' 'o' 'l' 'l' 'a'] ['b']
# ['h' 'e' 'r' ' ' 'c' 'o' 'l' 'l' 'a' 'b'] ['o']
# ['e' 'r' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o'] ['r']
# ['r' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r'] ['a']
# [' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a'] ['t']
# ['c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't'] ['i']
# ['o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i'] ['o']
# ['l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o'] ['n']
# ['l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n'] ['.']
# ['a' 'b' 'o' 'r' 'a' 't' 'i' 'o' 'n' '.'] [' ']
# ['b' 'o' 'r' 'a' 't' 'i' 'o' 'n' '.' ' '] ['b']
# ['o' 'r' 'a' 't' 'i' 'o' 'n' '.' ' ' 'b'] ['u']
# ['r' 'a' 't' 'i' 'o' 'n' '.' ' ' 'b' 'u'] ['i']
# ['a' 't' 'i' 'o' 'n' '.' ' ' 'b' 'u' 'i'] ['l']
# ['t' 'i' 'o' 'n' '.' ' ' 'b' 'u' 'i' 'l'] ['d']
# ['i' 'o' 'n' '.' ' ' 'b' 'u' 'i' 'l' 'd'] ['i']
# ['o' 'n' '.' ' ' 'b' 'u' 'i' 'l' 'd' 'i'] ['n']
# ['n' '.' ' ' 'b' 'u' 'i' 'l' 'd' 'i' 'n'] ['g']
# ['.' ' ' 'b' 'u' 'i' 'l' 'd' 'i' 'n' 'g'] [' ']
# [' ' 'b' 'u' 'i' 'l' 'd' 'i' 'n' 'g' ' '] ['o']
# ['b' 'u' 'i' 'l' 'd' 'i' 'n' 'g' ' ' 'o'] ['f']
# ['u' 'i' 'l' 'd' 'i' 'n' 'g' ' ' 'o' 'f'] ['f']
# ['i' 'l' 'd' 'i' 'n' 'g' ' ' 'o' 'f' 'f'] [' ']
# ['l' 'd' 'i' 'n' 'g' ' ' 'o' 'f' 'f' ' '] ['o']
# ['d' 'i' 'n' 'g' ' ' 'o' 'f' 'f' ' ' 'o'] ['f']
# ['i' 'n' 'g' ' ' 'o' 'f' 'f' ' ' 'o' 'f'] [' ']
# ['n' 'g' ' ' 'o' 'f' 'f' ' ' 'o' 'f' ' '] ['e']
# ['g' ' ' 'o' 'f' 'f' ' ' 'o' 'f' ' ' 'e'] ['a']
# [' ' 'o' 'f' 'f' ' ' 'o' 'f' ' ' 'e' 'a'] ['r']
# ['o' 'f' 'f' ' ' 'o' 'f' ' ' 'e' 'a' 'r'] ['l']
# ['f' 'f' ' ' 'o' 'f' ' ' 'e' 'a' 'r' 'l'] ['i']
# ['f' ' ' 'o' 'f' ' ' 'e' 'a' 'r' 'l' 'i'] ['e']
# [' ' 'o' 'f' ' ' 'e' 'a' 'r' 'l' 'i' 'e'] ['r']
# ['o' 'f' ' ' 'e' 'a' 'r' 'l' 'i' 'e' 'r'] [' ']
# ['f' ' ' 'e' 'a' 'r' 'l' 'i' 'e' 'r' ' '] ['d']
# [' ' 'e' 'a' 'r' 'l' 'i' 'e' 'r' ' ' 'd'] ['i']
# ['e' 'a' 'r' 'l' 'i' 'e' 'r' ' ' 'd' 'i'] ['s']
# ['a' 'r' 'l' 'i' 'e' 'r' ' ' 'd' 'i' 's'] ['c']
# ['r' 'l' 'i' 'e' 'r' ' ' 'd' 'i' 's' 'c'] ['u']
# ['l' 'i' 'e' 'r' ' ' 'd' 'i' 's' 'c' 'u'] ['r']
# ['i' 'e' 'r' ' ' 'd' 'i' 's' 'c' 'u' 'r'] ['s']
# ['e' 'r' ' ' 'd' 'i' 's' 'c' 'u' 'r' 's'] ['i']
# ['r' ' ' 'd' 'i' 's' 'c' 'u' 'r' 's' 'i'] ['v']
# [' ' 'd' 'i' 's' 'c' 'u' 'r' 's' 'i' 'v'] ['e']
# ['d' 'i' 's' 'c' 'u' 'r' 's' 'i' 'v' 'e'] [' ']
# ['i' 's' 'c' 'u' 'r' 's' 'i' 'v' 'e' ' '] ['a']
# ['s' 'c' 'u' 'r' 's' 'i' 'v' 'e' ' ' 'a'] ['n']
# ['c' 'u' 'r' 's' 'i' 'v' 'e' ' ' 'a' 'n'] ['a']
# ['u' 'r' 's' 'i' 'v' 'e' ' ' 'a' 'n' 'a'] ['l']
# ['r' 's' 'i' 'v' 'e' ' ' 'a' 'n' 'a' 'l'] ['y']
# ['s' 'i' 'v' 'e' ' ' 'a' 'n' 'a' 'l' 'y'] ['s']
# ['i' 'v' 'e' ' ' 'a' 'n' 'a' 'l' 'y' 's'] ['e']
# ['v' 'e' ' ' 'a' 'n' 'a' 'l' 'y' 's' 'e'] ['s']
# ['e' ' ' 'a' 'n' 'a' 'l' 'y' 's' 'e' 's'] [' ']
# [' ' 'a' 'n' 'a' 'l' 'y' 's' 'e' 's' ' '] ['o']
# ['a' 'n' 'a' 'l' 'y' 's' 'e' 's' ' ' 'o'] ['f']
# ['n' 'a' 'l' 'y' 's' 'e' 's' ' ' 'o' 'f'] [' ']
# ['a' 'l' 'y' 's' 'e' 's' ' ' 'o' 'f' ' '] ['t']
# ['l' 'y' 's' 'e' 's' ' ' 'o' 'f' ' ' 't'] ['e']
# ['y' 's' 'e' 's' ' ' 'o' 'f' ' ' 't' 'e'] ['a']
# ['s' 'e' 's' ' ' 'o' 'f' ' ' 't' 'e' 'a'] ['c']
# ['e' 's' ' ' 'o' 'f' ' ' 't' 'e' 'a' 'c'] ['h']
# ['s' ' ' 'o' 'f' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# [' ' 'o' 'f' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['o' 'f' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] ['s']
# ['f' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's'] ['’']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’'] [' ']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' '] ['c']
# ['e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'c'] ['o']
# ['a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'c' 'o'] ['l']
# ['c' 'h' 'e' 'r' 's' '’' ' ' 'c' 'o' 'l'] ['l']
# ['h' 'e' 'r' 's' '’' ' ' 'c' 'o' 'l' 'l'] ['e']
# ['e' 'r' 's' '’' ' ' 'c' 'o' 'l' 'l' 'e'] ['g']
# ['r' 's' '’' ' ' 'c' 'o' 'l' 'l' 'e' 'g'] ['i']
# ['s' '’' ' ' 'c' 'o' 'l' 'l' 'e' 'g' 'i'] ['a']
# ['’' ' ' 'c' 'o' 'l' 'l' 'e' 'g' 'i' 'a'] ['l']
# [' ' 'c' 'o' 'l' 'l' 'e' 'g' 'i' 'a' 'l'] [' ']
# ['c' 'o' 'l' 'l' 'e' 'g' 'i' 'a' 'l' ' '] ['l']
# ['o' 'l' 'l' 'e' 'g' 'i' 'a' 'l' ' ' 'l'] ['e']
# ['l' 'l' 'e' 'g' 'i' 'a' 'l' ' ' 'l' 'e'] ['a']
# ['l' 'e' 'g' 'i' 'a' 'l' ' ' 'l' 'e' 'a'] ['r']
# ['e' 'g' 'i' 'a' 'l' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['g' 'i' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['i' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] [',']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ','] [' ']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ',' ' '] ['w']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' ',' ' ' 'w'] ['e']
# ['a' 'r' 'n' 'i' 'n' 'g' ',' ' ' 'w' 'e'] [' ']
# ['r' 'n' 'i' 'n' 'g' ',' ' ' 'w' 'e' ' '] ['d']
# ['n' 'i' 'n' 'g' ',' ' ' 'w' 'e' ' ' 'd'] ['e']
# ['i' 'n' 'g' ',' ' ' 'w' 'e' ' ' 'd' 'e'] ['v']
# ['n' 'g' ',' ' ' 'w' 'e' ' ' 'd' 'e' 'v'] ['e']
# ['g' ',' ' ' 'w' 'e' ' ' 'd' 'e' 'v' 'e'] ['l']
# [',' ' ' 'w' 'e' ' ' 'd' 'e' 'v' 'e' 'l'] ['o']
# [' ' 'w' 'e' ' ' 'd' 'e' 'v' 'e' 'l' 'o'] ['p']
# ['w' 'e' ' ' 'd' 'e' 'v' 'e' 'l' 'o' 'p'] ['e']
# ['e' ' ' 'd' 'e' 'v' 'e' 'l' 'o' 'p' 'e'] ['d']
# [' ' 'd' 'e' 'v' 'e' 'l' 'o' 'p' 'e' 'd'] [' ']
# ['d' 'e' 'v' 'e' 'l' 'o' 'p' 'e' 'd' ' '] ['a']
# ['e' 'v' 'e' 'l' 'o' 'p' 'e' 'd' ' ' 'a'] [' ']
# ['v' 'e' 'l' 'o' 'p' 'e' 'd' ' ' 'a' ' '] ['t']
# ['e' 'l' 'o' 'p' 'e' 'd' ' ' 'a' ' ' 't'] ['a']
# ['l' 'o' 'p' 'e' 'd' ' ' 'a' ' ' 't' 'a'] ['x']
# ['o' 'p' 'e' 'd' ' ' 'a' ' ' 't' 'a' 'x'] ['o']
# ['p' 'e' 'd' ' ' 'a' ' ' 't' 'a' 'x' 'o'] ['n']
# ['e' 'd' ' ' 'a' ' ' 't' 'a' 'x' 'o' 'n'] ['o']
# ['d' ' ' 'a' ' ' 't' 'a' 'x' 'o' 'n' 'o'] ['m']
# [' ' 'a' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm'] ['y']
# ['a' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y'] [' ']
# [' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' '] ['t']
# ['t' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 't'] ['o']
# ['a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 't' 'o'] [' ']
# ['x' 'o' 'n' 'o' 'm' 'y' ' ' 't' 'o' ' '] ['d']
# ['o' 'n' 'o' 'm' 'y' ' ' 't' 'o' ' ' 'd'] ['e']
# ['n' 'o' 'm' 'y' ' ' 't' 'o' ' ' 'd' 'e'] ['s']
# ['o' 'm' 'y' ' ' 't' 'o' ' ' 'd' 'e' 's'] ['c']
# ['m' 'y' ' ' 't' 'o' ' ' 'd' 'e' 's' 'c'] ['r']
# ['y' ' ' 't' 'o' ' ' 'd' 'e' 's' 'c' 'r'] ['i']
# [' ' 't' 'o' ' ' 'd' 'e' 's' 'c' 'r' 'i'] ['b']
# ['t' 'o' ' ' 'd' 'e' 's' 'c' 'r' 'i' 'b'] ['e']
# ['o' ' ' 'd' 'e' 's' 'c' 'r' 'i' 'b' 'e'] [' ']
# [' ' 'd' 'e' 's' 'c' 'r' 'i' 'b' 'e' ' '] ['h']
# ['d' 'e' 's' 'c' 'r' 'i' 'b' 'e' ' ' 'h'] ['o']
# ['e' 's' 'c' 'r' 'i' 'b' 'e' ' ' 'h' 'o'] ['w']
# ['s' 'c' 'r' 'i' 'b' 'e' ' ' 'h' 'o' 'w'] [' ']
# ['c' 'r' 'i' 'b' 'e' ' ' 'h' 'o' 'w' ' '] ['c']
# ['r' 'i' 'b' 'e' ' ' 'h' 'o' 'w' ' ' 'c'] ['o']
# ['i' 'b' 'e' ' ' 'h' 'o' 'w' ' ' 'c' 'o'] ['n']
# ['b' 'e' ' ' 'h' 'o' 'w' ' ' 'c' 'o' 'n'] ['v']
# ['e' ' ' 'h' 'o' 'w' ' ' 'c' 'o' 'n' 'v'] ['e']
# [' ' 'h' 'o' 'w' ' ' 'c' 'o' 'n' 'v' 'e'] ['r']
# ['h' 'o' 'w' ' ' 'c' 'o' 'n' 'v' 'e' 'r'] ['s']
# ['o' 'w' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's'] ['a']
# ['w' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a'] ['t']
# [' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't'] ['i']
# ['c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i'] ['o']
# ['o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o'] ['n']
# ['n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n'] ['a']
# ['v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n' 'a'] ['l']
# ['e' 'r' 's' 'a' 't' 'i' 'o' 'n' 'a' 'l'] [' ']
# ['r' 's' 'a' 't' 'i' 'o' 'n' 'a' 'l' ' '] ['p']
# ['s' 'a' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'p'] ['r']
# ['a' 't' 'i' 'o' 'n' 'a' 'l' ' ' 'p' 'r'] ['o']
# ['t' 'i' 'o' 'n' 'a' 'l' ' ' 'p' 'r' 'o'] ['c']
# ['i' 'o' 'n' 'a' 'l' ' ' 'p' 'r' 'o' 'c'] ['e']
# ['o' 'n' 'a' 'l' ' ' 'p' 'r' 'o' 'c' 'e'] ['s']
# ['n' 'a' 'l' ' ' 'p' 'r' 'o' 'c' 'e' 's'] ['s']
# ['a' 'l' ' ' 'p' 'r' 'o' 'c' 'e' 's' 's'] ['e']
# ['l' ' ' 'p' 'r' 'o' 'c' 'e' 's' 's' 'e'] ['s']
# [' ' 'p' 'r' 'o' 'c' 'e' 's' 's' 'e' 's'] [' ']
# ['p' 'r' 'o' 'c' 'e' 's' 's' 'e' 's' ' '] ['d']
# ['r' 'o' 'c' 'e' 's' 's' 'e' 's' ' ' 'd'] ['i']
# ['o' 'c' 'e' 's' 's' 'e' 's' ' ' 'd' 'i'] ['f']
# ['c' 'e' 's' 's' 'e' 's' ' ' 'd' 'i' 'f'] ['f']
# ['e' 's' 's' 'e' 's' ' ' 'd' 'i' 'f' 'f'] ['e']
# ['s' 's' 'e' 's' ' ' 'd' 'i' 'f' 'f' 'e'] ['r']
# ['s' 'e' 's' ' ' 'd' 'i' 'f' 'f' 'e' 'r'] ['e']
# ['e' 's' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e'] ['n']
# ['s' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n'] ['t']
# [' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't'] ['i']
# ['d' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't' 'i'] ['a']
# ['i' 'f' 'f' 'e' 'r' 'e' 'n' 't' 'i' 'a'] ['l']
# ['f' 'f' 'e' 'r' 'e' 'n' 't' 'i' 'a' 'l'] ['l']
# ['f' 'e' 'r' 'e' 'n' 't' 'i' 'a' 'l' 'l'] ['y']
# ['e' 'r' 'e' 'n' 't' 'i' 'a' 'l' 'l' 'y'] [' ']
# ['r' 'e' 'n' 't' 'i' 'a' 'l' 'l' 'y' ' '] ['s']
# ['e' 'n' 't' 'i' 'a' 'l' 'l' 'y' ' ' 's'] ['u']
# ['n' 't' 'i' 'a' 'l' 'l' 'y' ' ' 's' 'u'] ['p']
# ['t' 'i' 'a' 'l' 'l' 'y' ' ' 's' 'u' 'p'] ['p']
# ['i' 'a' 'l' 'l' 'y' ' ' 's' 'u' 'p' 'p'] ['o']
# ['a' 'l' 'l' 'y' ' ' 's' 'u' 'p' 'p' 'o'] ['r']
# ['l' 'l' 'y' ' ' 's' 'u' 'p' 'p' 'o' 'r'] ['t']
# ['l' 'y' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't'] [' ']
# ['y' ' ' 's' 'u' 'p' 'p' 'o' 'r' 't' ' '] ['t']
# [' ' 's' 'u' 'p' 'p' 'o' 'r' 't' ' ' 't'] ['e']
# ['s' 'u' 'p' 'p' 'o' 'r' 't' ' ' 't' 'e'] ['a']
# ['u' 'p' 'p' 'o' 'r' 't' ' ' 't' 'e' 'a'] ['c']
# ['p' 'p' 'o' 'r' 't' ' ' 't' 'e' 'a' 'c'] ['h']
# ['p' 'o' 'r' 't' ' ' 't' 'e' 'a' 'c' 'h'] ['e']
# ['o' 'r' 't' ' ' 't' 'e' 'a' 'c' 'h' 'e'] ['r']
# ['r' 't' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r'] ['s']
# ['t' ' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's'] ['’']
# [' ' 't' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’'] [' ']
# ['t' 'e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' '] ['p']
# ['e' 'a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'p'] ['r']
# ['a' 'c' 'h' 'e' 'r' 's' '’' ' ' 'p' 'r'] ['o']
# ['c' 'h' 'e' 'r' 's' '’' ' ' 'p' 'r' 'o'] ['f']
# ['h' 'e' 'r' 's' '’' ' ' 'p' 'r' 'o' 'f'] ['e']
# ['e' 'r' 's' '’' ' ' 'p' 'r' 'o' 'f' 'e'] ['s']
# ['r' 's' '’' ' ' 'p' 'r' 'o' 'f' 'e' 's'] ['s']
# ['s' '’' ' ' 'p' 'r' 'o' 'f' 'e' 's' 's'] ['i']
# ['’' ' ' 'p' 'r' 'o' 'f' 'e' 's' 's' 'i'] ['o']
# [' ' 'p' 'r' 'o' 'f' 'e' 's' 's' 'i' 'o'] ['n']
# ['p' 'r' 'o' 'f' 'e' 's' 's' 'i' 'o' 'n'] ['a']
# ['r' 'o' 'f' 'e' 's' 's' 'i' 'o' 'n' 'a'] ['l']
# ['o' 'f' 'e' 's' 's' 'i' 'o' 'n' 'a' 'l'] [' ']
# ['f' 'e' 's' 's' 'i' 'o' 'n' 'a' 'l' ' '] ['l']
# ['e' 's' 's' 'i' 'o' 'n' 'a' 'l' ' ' 'l'] ['e']
# ['s' 's' 'i' 'o' 'n' 'a' 'l' ' ' 'l' 'e'] ['a']
# ['s' 'i' 'o' 'n' 'a' 'l' ' ' 'l' 'e' 'a'] ['r']
# ['i' 'o' 'n' 'a' 'l' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['o' 'n' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['n' 'a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['a' 'l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['l' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] ['.']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' '.'] [' ']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' '.' ' '] ['w']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' '.' ' ' 'w'] ['e']
# ['a' 'r' 'n' 'i' 'n' 'g' '.' ' ' 'w' 'e'] [' ']
# ['r' 'n' 'i' 'n' 'g' '.' ' ' 'w' 'e' ' '] ['u']
# ['n' 'i' 'n' 'g' '.' ' ' 'w' 'e' ' ' 'u'] ['s']
# ['i' 'n' 'g' '.' ' ' 'w' 'e' ' ' 'u' 's'] ['e']
# ['n' 'g' '.' ' ' 'w' 'e' ' ' 'u' 's' 'e'] ['d']
# ['g' '.' ' ' 'w' 'e' ' ' 'u' 's' 'e' 'd'] [' ']
# ['.' ' ' 'w' 'e' ' ' 'u' 's' 'e' 'd' ' '] ['t']
# [' ' 'w' 'e' ' ' 'u' 's' 'e' 'd' ' ' 't'] ['h']
# ['w' 'e' ' ' 'u' 's' 'e' 'd' ' ' 't' 'h'] ['e']
# ['e' ' ' 'u' 's' 'e' 'd' ' ' 't' 'h' 'e'] [' ']
# [' ' 'u' 's' 'e' 'd' ' ' 't' 'h' 'e' ' '] ['t']
# ['u' 's' 'e' 'd' ' ' 't' 'h' 'e' ' ' 't'] ['a']
# ['s' 'e' 'd' ' ' 't' 'h' 'e' ' ' 't' 'a'] ['x']
# ['e' 'd' ' ' 't' 'h' 'e' ' ' 't' 'a' 'x'] ['o']
# ['d' ' ' 't' 'h' 'e' ' ' 't' 'a' 'x' 'o'] ['n']
# [' ' 't' 'h' 'e' ' ' 't' 'a' 'x' 'o' 'n'] ['o']
# ['t' 'h' 'e' ' ' 't' 'a' 'x' 'o' 'n' 'o'] ['m']
# ['h' 'e' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm'] ['y']
# ['e' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y'] [' ']
# [' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' '] ['t']
# ['t' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 't'] ['o']
# ['a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 't' 'o'] [' ']
# ['x' 'o' 'n' 'o' 'm' 'y' ' ' 't' 'o' ' '] ['c']
# ['o' 'n' 'o' 'm' 'y' ' ' 't' 'o' ' ' 'c'] ['o']
# ['n' 'o' 'm' 'y' ' ' 't' 'o' ' ' 'c' 'o'] ['d']
# ['o' 'm' 'y' ' ' 't' 'o' ' ' 'c' 'o' 'd'] ['e']
# ['m' 'y' ' ' 't' 'o' ' ' 'c' 'o' 'd' 'e'] [' ']
# ['y' ' ' 't' 'o' ' ' 'c' 'o' 'd' 'e' ' '] ['o']
# [' ' 't' 'o' ' ' 'c' 'o' 'd' 'e' ' ' 'o'] ['u']
# ['t' 'o' ' ' 'c' 'o' 'd' 'e' ' ' 'o' 'u'] ['r']
# ['o' ' ' 'c' 'o' 'd' 'e' ' ' 'o' 'u' 'r'] [' ']
# [' ' 'c' 'o' 'd' 'e' ' ' 'o' 'u' 'r' ' '] ['c']
# ['c' 'o' 'd' 'e' ' ' 'o' 'u' 'r' ' ' 'c'] ['o']
# ['o' 'd' 'e' ' ' 'o' 'u' 'r' ' ' 'c' 'o'] ['r']
# ['d' 'e' ' ' 'o' 'u' 'r' ' ' 'c' 'o' 'r'] ['p']
# ['e' ' ' 'o' 'u' 'r' ' ' 'c' 'o' 'r' 'p'] ['u']
# [' ' 'o' 'u' 'r' ' ' 'c' 'o' 'r' 'p' 'u'] ['s']
# ['o' 'u' 'r' ' ' 'c' 'o' 'r' 'p' 'u' 's'] [',']
# ['u' 'r' ' ' 'c' 'o' 'r' 'p' 'u' 's' ','] [' ']
# ['r' ' ' 'c' 'o' 'r' 'p' 'u' 's' ',' ' '] ['w']
# [' ' 'c' 'o' 'r' 'p' 'u' 's' ',' ' ' 'w'] ['i']
# ['c' 'o' 'r' 'p' 'u' 's' ',' ' ' 'w' 'i'] ['t']
# ['o' 'r' 'p' 'u' 's' ',' ' ' 'w' 'i' 't'] ['h']
# ['r' 'p' 'u' 's' ',' ' ' 'w' 'i' 't' 'h'] [' ']
# ['p' 'u' 's' ',' ' ' 'w' 'i' 't' 'h' ' '] ['e']
# ['u' 's' ',' ' ' 'w' 'i' 't' 'h' ' ' 'e'] ['a']
# ['s' ',' ' ' 'w' 'i' 't' 'h' ' ' 'e' 'a'] ['c']
# [',' ' ' 'w' 'i' 't' 'h' ' ' 'e' 'a' 'c'] ['h']
# [' ' 'w' 'i' 't' 'h' ' ' 'e' 'a' 'c' 'h'] [' ']
# ['w' 'i' 't' 'h' ' ' 'e' 'a' 'c' 'h' ' '] ['c']
# ['i' 't' 'h' ' ' 'e' 'a' 'c' 'h' ' ' 'c'] ['a']
# ['t' 'h' ' ' 'e' 'a' 'c' 'h' ' ' 'c' 'a'] ['t']
# ['h' ' ' 'e' 'a' 'c' 'h' ' ' 'c' 'a' 't'] ['e']
# [' ' 'e' 'a' 'c' 'h' ' ' 'c' 'a' 't' 'e'] ['g']
# ['e' 'a' 'c' 'h' ' ' 'c' 'a' 't' 'e' 'g'] ['o']
# ['a' 'c' 'h' ' ' 'c' 'a' 't' 'e' 'g' 'o'] ['r']
# ['c' 'h' ' ' 'c' 'a' 't' 'e' 'g' 'o' 'r'] ['y']
# ['h' ' ' 'c' 'a' 't' 'e' 'g' 'o' 'r' 'y'] [' ']
# [' ' 'c' 'a' 't' 'e' 'g' 'o' 'r' 'y' ' '] ['s']
# ['c' 'a' 't' 'e' 'g' 'o' 'r' 'y' ' ' 's'] ['i']
# ['a' 't' 'e' 'g' 'o' 'r' 'y' ' ' 's' 'i'] ['g']
# ['t' 'e' 'g' 'o' 'r' 'y' ' ' 's' 'i' 'g'] ['n']
# ['e' 'g' 'o' 'r' 'y' ' ' 's' 'i' 'g' 'n'] ['a']
# ['g' 'o' 'r' 'y' ' ' 's' 'i' 'g' 'n' 'a'] ['l']
# ['o' 'r' 'y' ' ' 's' 'i' 'g' 'n' 'a' 'l'] ['i']
# ['r' 'y' ' ' 's' 'i' 'g' 'n' 'a' 'l' 'i'] ['n']
# ['y' ' ' 's' 'i' 'g' 'n' 'a' 'l' 'i' 'n'] ['g']
# [' ' 's' 'i' 'g' 'n' 'a' 'l' 'i' 'n' 'g'] [' ']
# ['s' 'i' 'g' 'n' 'a' 'l' 'i' 'n' 'g' ' '] ['d']
# ['i' 'g' 'n' 'a' 'l' 'i' 'n' 'g' ' ' 'd'] ['i']
# ['g' 'n' 'a' 'l' 'i' 'n' 'g' ' ' 'd' 'i'] ['f']
# ['n' 'a' 'l' 'i' 'n' 'g' ' ' 'd' 'i' 'f'] ['f']
# ['a' 'l' 'i' 'n' 'g' ' ' 'd' 'i' 'f' 'f'] ['e']
# ['l' 'i' 'n' 'g' ' ' 'd' 'i' 'f' 'f' 'e'] ['r']
# ['i' 'n' 'g' ' ' 'd' 'i' 'f' 'f' 'e' 'r'] ['e']
# ['n' 'g' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e'] ['n']
# ['g' ' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n'] ['t']
# [' ' 'd' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't'] [' ']
# ['d' 'i' 'f' 'f' 'e' 'r' 'e' 'n' 't' ' '] ['l']
# ['i' 'f' 'f' 'e' 'r' 'e' 'n' 't' ' ' 'l'] ['e']
# ['f' 'f' 'e' 'r' 'e' 'n' 't' ' ' 'l' 'e'] ['a']
# ['f' 'e' 'r' 'e' 'n' 't' ' ' 'l' 'e' 'a'] ['r']
# ['e' 'r' 'e' 'n' 't' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['r' 'e' 'n' 't' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['e' 'n' 't' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['n' 't' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['t' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] [' ']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' '] ['o']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o'] ['p']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p'] ['p']
# ['a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p'] ['o']
# ['r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o'] ['r']
# ['n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r'] ['t']
# ['i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't'] ['u']
# ['n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u'] ['n']
# ['g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n'] ['i']
# [' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i'] ['t']
# ['o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't'] ['i']
# ['p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i'] ['e']
# ['p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e'] ['s']
# ['o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's'] ['.']
# ['r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's' '.'] [' ']
# ['t' 'u' 'n' 'i' 't' 'i' 'e' 's' '.' ' '] ['i']
# ['u' 'n' 'i' 't' 'i' 'e' 's' '.' ' ' 'i'] ['n']
# ['n' 'i' 't' 'i' 'e' 's' '.' ' ' 'i' 'n'] [' ']
# ['i' 't' 'i' 'e' 's' '.' ' ' 'i' 'n' ' '] ['t']
# ['t' 'i' 'e' 's' '.' ' ' 'i' 'n' ' ' 't'] ['h']
# ['i' 'e' 's' '.' ' ' 'i' 'n' ' ' 't' 'h'] ['i']
# ['e' 's' '.' ' ' 'i' 'n' ' ' 't' 'h' 'i'] ['s']
# ['s' '.' ' ' 'i' 'n' ' ' 't' 'h' 'i' 's'] [' ']
# ['.' ' ' 'i' 'n' ' ' 't' 'h' 'i' 's' ' '] ['a']
# [' ' 'i' 'n' ' ' 't' 'h' 'i' 's' ' ' 'a'] ['r']
# ['i' 'n' ' ' 't' 'h' 'i' 's' ' ' 'a' 'r'] ['t']
# ['n' ' ' 't' 'h' 'i' 's' ' ' 'a' 'r' 't'] ['i']
# [' ' 't' 'h' 'i' 's' ' ' 'a' 'r' 't' 'i'] ['c']
# ['t' 'h' 'i' 's' ' ' 'a' 'r' 't' 'i' 'c'] ['l']
# ['h' 'i' 's' ' ' 'a' 'r' 't' 'i' 'c' 'l'] ['e']
# ['i' 's' ' ' 'a' 'r' 't' 'i' 'c' 'l' 'e'] [',']
# ['s' ' ' 'a' 'r' 't' 'i' 'c' 'l' 'e' ','] [' ']
# [' ' 'a' 'r' 't' 'i' 'c' 'l' 'e' ',' ' '] ['w']
# ['a' 'r' 't' 'i' 'c' 'l' 'e' ',' ' ' 'w'] ['e']
# ['r' 't' 'i' 'c' 'l' 'e' ',' ' ' 'w' 'e'] [' ']
# ['t' 'i' 'c' 'l' 'e' ',' ' ' 'w' 'e' ' '] ['p']
# ['i' 'c' 'l' 'e' ',' ' ' 'w' 'e' ' ' 'p'] ['r']
# ['c' 'l' 'e' ',' ' ' 'w' 'e' ' ' 'p' 'r'] ['e']
# ['l' 'e' ',' ' ' 'w' 'e' ' ' 'p' 'r' 'e'] ['s']
# ['e' ',' ' ' 'w' 'e' ' ' 'p' 'r' 'e' 's'] ['e']
# [',' ' ' 'w' 'e' ' ' 'p' 'r' 'e' 's' 'e'] ['n']
# [' ' 'w' 'e' ' ' 'p' 'r' 'e' 's' 'e' 'n'] ['t']
# ['w' 'e' ' ' 'p' 'r' 'e' 's' 'e' 'n' 't'] [' ']
# ['e' ' ' 'p' 'r' 'e' 's' 'e' 'n' 't' ' '] ['t']
# [' ' 'p' 'r' 'e' 's' 'e' 'n' 't' ' ' 't'] ['h']
# ['p' 'r' 'e' 's' 'e' 'n' 't' ' ' 't' 'h'] ['e']
# ['r' 'e' 's' 'e' 'n' 't' ' ' 't' 'h' 'e'] [' ']
# ['e' 's' 'e' 'n' 't' ' ' 't' 'h' 'e' ' '] ['t']
# ['s' 'e' 'n' 't' ' ' 't' 'h' 'e' ' ' 't'] ['a']
# ['e' 'n' 't' ' ' 't' 'h' 'e' ' ' 't' 'a'] ['x']
# ['n' 't' ' ' 't' 'h' 'e' ' ' 't' 'a' 'x'] ['o']
# ['t' ' ' 't' 'h' 'e' ' ' 't' 'a' 'x' 'o'] ['n']
# [' ' 't' 'h' 'e' ' ' 't' 'a' 'x' 'o' 'n'] ['o']
# ['t' 'h' 'e' ' ' 't' 'a' 'x' 'o' 'n' 'o'] ['m']
# ['h' 'e' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm'] ['y']
# ['e' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y'] [',']
# [' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ','] [' ']
# ['t' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ',' ' '] ['i']
# ['a' 'x' 'o' 'n' 'o' 'm' 'y' ',' ' ' 'i'] ['l']
# ['x' 'o' 'n' 'o' 'm' 'y' ',' ' ' 'i' 'l'] ['l']
# ['o' 'n' 'o' 'm' 'y' ',' ' ' 'i' 'l' 'l'] ['u']
# ['n' 'o' 'm' 'y' ',' ' ' 'i' 'l' 'l' 'u'] ['s']
# ['o' 'm' 'y' ',' ' ' 'i' 'l' 'l' 'u' 's'] ['t']
# ['m' 'y' ',' ' ' 'i' 'l' 'l' 'u' 's' 't'] ['r']
# ['y' ',' ' ' 'i' 'l' 'l' 'u' 's' 't' 'r'] ['a']
# [',' ' ' 'i' 'l' 'l' 'u' 's' 't' 'r' 'a'] ['t']
# [' ' 'i' 'l' 'l' 'u' 's' 't' 'r' 'a' 't'] ['e']
# ['i' 'l' 'l' 'u' 's' 't' 'r' 'a' 't' 'e'] [' ']
# ['l' 'l' 'u' 's' 't' 'r' 'a' 't' 'e' ' '] ['t']
# ['l' 'u' 's' 't' 'r' 'a' 't' 'e' ' ' 't'] ['h']
# ['u' 's' 't' 'r' 'a' 't' 'e' ' ' 't' 'h'] ['e']
# ['s' 't' 'r' 'a' 't' 'e' ' ' 't' 'h' 'e'] [' ']
# ['t' 'r' 'a' 't' 'e' ' ' 't' 'h' 'e' ' '] ['c']
# ['r' 'a' 't' 'e' ' ' 't' 'h' 'e' ' ' 'c'] ['a']
# ['a' 't' 'e' ' ' 't' 'h' 'e' ' ' 'c' 'a'] ['t']
# ['t' 'e' ' ' 't' 'h' 'e' ' ' 'c' 'a' 't'] ['e']
# ['e' ' ' 't' 'h' 'e' ' ' 'c' 'a' 't' 'e'] ['g']
# [' ' 't' 'h' 'e' ' ' 'c' 'a' 't' 'e' 'g'] ['o']
# ['t' 'h' 'e' ' ' 'c' 'a' 't' 'e' 'g' 'o'] ['r']
# ['h' 'e' ' ' 'c' 'a' 't' 'e' 'g' 'o' 'r'] ['i']
# ['e' ' ' 'c' 'a' 't' 'e' 'g' 'o' 'r' 'i'] ['e']
# [' ' 'c' 'a' 't' 'e' 'g' 'o' 'r' 'i' 'e'] ['s']
# ['c' 'a' 't' 'e' 'g' 'o' 'r' 'i' 'e' 's'] [',']
# ['a' 't' 'e' 'g' 'o' 'r' 'i' 'e' 's' ','] [' ']
# ['t' 'e' 'g' 'o' 'r' 'i' 'e' 's' ',' ' '] ['a']
# ['e' 'g' 'o' 'r' 'i' 'e' 's' ',' ' ' 'a'] ['n']
# ['g' 'o' 'r' 'i' 'e' 's' ',' ' ' 'a' 'n'] ['d']
# ['o' 'r' 'i' 'e' 's' ',' ' ' 'a' 'n' 'd'] [' ']
# ['r' 'i' 'e' 's' ',' ' ' 'a' 'n' 'd' ' '] ['r']
# ['i' 'e' 's' ',' ' ' 'a' 'n' 'd' ' ' 'r'] ['e']
# ['e' 's' ',' ' ' 'a' 'n' 'd' ' ' 'r' 'e'] ['p']
# ['s' ',' ' ' 'a' 'n' 'd' ' ' 'r' 'e' 'p'] ['o']
# [',' ' ' 'a' 'n' 'd' ' ' 'r' 'e' 'p' 'o'] ['r']
# [' ' 'a' 'n' 'd' ' ' 'r' 'e' 'p' 'o' 'r'] ['t']
# ['a' 'n' 'd' ' ' 'r' 'e' 'p' 'o' 'r' 't'] [' ']
# ['n' 'd' ' ' 'r' 'e' 'p' 'o' 'r' 't' ' '] ['t']
# ['d' ' ' 'r' 'e' 'p' 'o' 'r' 't' ' ' 't'] ['h']
# [' ' 'r' 'e' 'p' 'o' 'r' 't' ' ' 't' 'h'] ['e']
# ['r' 'e' 'p' 'o' 'r' 't' ' ' 't' 'h' 'e'] [' ']
# ['e' 'p' 'o' 'r' 't' ' ' 't' 'h' 'e' ' '] ['o']
# ['p' 'o' 'r' 't' ' ' 't' 'h' 'e' ' ' 'o'] ['v']
# ['o' 'r' 't' ' ' 't' 'h' 'e' ' ' 'o' 'v'] ['e']
# ['r' 't' ' ' 't' 'h' 'e' ' ' 'o' 'v' 'e'] ['r']
# ['t' ' ' 't' 'h' 'e' ' ' 'o' 'v' 'e' 'r'] ['a']
# [' ' 't' 'h' 'e' ' ' 'o' 'v' 'e' 'r' 'a'] ['l']
# ['t' 'h' 'e' ' ' 'o' 'v' 'e' 'r' 'a' 'l'] ['l']
# ['h' 'e' ' ' 'o' 'v' 'e' 'r' 'a' 'l' 'l'] [' ']
# ['e' ' ' 'o' 'v' 'e' 'r' 'a' 'l' 'l' ' '] ['d']
# [' ' 'o' 'v' 'e' 'r' 'a' 'l' 'l' ' ' 'd'] ['e']
# ['o' 'v' 'e' 'r' 'a' 'l' 'l' ' ' 'd' 'e'] ['a']
# ['v' 'e' 'r' 'a' 'l' 'l' ' ' 'd' 'e' 'a'] ['r']
# ['e' 'r' 'a' 'l' 'l' ' ' 'd' 'e' 'a' 'r'] ['t']
# ['r' 'a' 'l' 'l' ' ' 'd' 'e' 'a' 'r' 't'] ['h']
# ['a' 'l' 'l' ' ' 'd' 'e' 'a' 'r' 't' 'h'] [' ']
# ['l' 'l' ' ' 'd' 'e' 'a' 'r' 't' 'h' ' '] ['o']
# ['l' ' ' 'd' 'e' 'a' 'r' 't' 'h' ' ' 'o'] ['f']
# [' ' 'd' 'e' 'a' 'r' 't' 'h' ' ' 'o' 'f'] [' ']
# ['d' 'e' 'a' 'r' 't' 'h' ' ' 'o' 'f' ' '] ['m']
# ['e' 'a' 'r' 't' 'h' ' ' 'o' 'f' ' ' 'm'] ['e']
# ['a' 'r' 't' 'h' ' ' 'o' 'f' ' ' 'm' 'e'] ['e']
# ['r' 't' 'h' ' ' 'o' 'f' ' ' 'm' 'e' 'e'] ['t']
# ['t' 'h' ' ' 'o' 'f' ' ' 'm' 'e' 'e' 't'] ['i']
# ['h' ' ' 'o' 'f' ' ' 'm' 'e' 'e' 't' 'i'] ['n']
# [' ' 'o' 'f' ' ' 'm' 'e' 'e' 't' 'i' 'n'] ['g']
# ['o' 'f' ' ' 'm' 'e' 'e' 't' 'i' 'n' 'g'] ['s']
# ['f' ' ' 'm' 'e' 'e' 't' 'i' 'n' 'g' 's'] [' ']
# [' ' 'm' 'e' 'e' 't' 'i' 'n' 'g' 's' ' '] ['w']
# ['m' 'e' 'e' 't' 'i' 'n' 'g' 's' ' ' 'w'] ['i']
# ['e' 'e' 't' 'i' 'n' 'g' 's' ' ' 'w' 'i'] ['t']
# ['e' 't' 'i' 'n' 'g' 's' ' ' 'w' 'i' 't'] ['h']
# ['t' 'i' 'n' 'g' 's' ' ' 'w' 'i' 't' 'h'] [' ']
# ['i' 'n' 'g' 's' ' ' 'w' 'i' 't' 'h' ' '] ['r']
# ['n' 'g' 's' ' ' 'w' 'i' 't' 'h' ' ' 'r'] ['i']
# ['g' 's' ' ' 'w' 'i' 't' 'h' ' ' 'r' 'i'] ['c']
# ['s' ' ' 'w' 'i' 't' 'h' ' ' 'r' 'i' 'c'] ['h']
# [' ' 'w' 'i' 't' 'h' ' ' 'r' 'i' 'c' 'h'] [' ']
# ['w' 'i' 't' 'h' ' ' 'r' 'i' 'c' 'h' ' '] ['l']
# ['i' 't' 'h' ' ' 'r' 'i' 'c' 'h' ' ' 'l'] ['e']
# ['t' 'h' ' ' 'r' 'i' 'c' 'h' ' ' 'l' 'e'] ['a']
# ['h' ' ' 'r' 'i' 'c' 'h' ' ' 'l' 'e' 'a'] ['r']
# [' ' 'r' 'i' 'c' 'h' ' ' 'l' 'e' 'a' 'r'] ['n']
# ['r' 'i' 'c' 'h' ' ' 'l' 'e' 'a' 'r' 'n'] ['i']
# ['i' 'c' 'h' ' ' 'l' 'e' 'a' 'r' 'n' 'i'] ['n']
# ['c' 'h' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n'] ['g']
# ['h' ' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g'] [' ']
# [' ' 'l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' '] ['o']
# ['l' 'e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o'] ['p']
# ['e' 'a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p'] ['p']
# ['a' 'r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p'] ['o']
# ['r' 'n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o'] ['r']
# ['n' 'i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r'] ['t']
# ['i' 'n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't'] ['u']
# ['n' 'g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u'] ['n']
# ['g' ' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n'] ['i']
# [' ' 'o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i'] ['t']
# ['o' 'p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't'] ['i']
# ['p' 'p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i'] ['e']
# ['p' 'o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e'] ['s']
# ['o' 'r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's'] [',']
# ['r' 't' 'u' 'n' 'i' 't' 'i' 'e' 's' ','] [' ']
# ['t' 'u' 'n' 'i' 't' 'i' 'e' 's' ',' ' '] ['e']
# ['u' 'n' 'i' 't' 'i' 'e' 's' ',' ' ' 'e'] ['v']
# ['n' 'i' 't' 'i' 'e' 's' ',' ' ' 'e' 'v'] ['e']
# ['i' 't' 'i' 'e' 's' ',' ' ' 'e' 'v' 'e'] ['n']
# ['t' 'i' 'e' 's' ',' ' ' 'e' 'v' 'e' 'n'] [' ']
# ['i' 'e' 's' ',' ' ' 'e' 'v' 'e' 'n' ' '] ['i']
# ['e' 's' ',' ' ' 'e' 'v' 'e' 'n' ' ' 'i'] ['n']
# ['s' ',' ' ' 'e' 'v' 'e' 'n' ' ' 'i' 'n'] [' ']
# [',' ' ' 'e' 'v' 'e' 'n' ' ' 'i' 'n' ' '] ['t']
# [' ' 'e' 'v' 'e' 'n' ' ' 'i' 'n' ' ' 't'] ['h']
# ['e' 'v' 'e' 'n' ' ' 'i' 'n' ' ' 't' 'h'] ['i']
# ['v' 'e' 'n' ' ' 'i' 'n' ' ' 't' 'h' 'i'] ['s']
# ['e' 'n' ' ' 'i' 'n' ' ' 't' 'h' 'i' 's'] [' ']
# ['n' ' ' 'i' 'n' ' ' 't' 'h' 'i' 's' ' '] ['p']
# [' ' 'i' 'n' ' ' 't' 'h' 'i' 's' ' ' 'p'] ['u']
# ['i' 'n' ' ' 't' 'h' 'i' 's' ' ' 'p' 'u'] ['r']
# ['n' ' ' 't' 'h' 'i' 's' ' ' 'p' 'u' 'r'] ['p']
# [' ' 't' 'h' 'i' 's' ' ' 'p' 'u' 'r' 'p'] ['o']
# ['t' 'h' 'i' 's' ' ' 'p' 'u' 'r' 'p' 'o'] ['s']
# ['h' 'i' 's' ' ' 'p' 'u' 'r' 'p' 'o' 's'] ['i']
# ['i' 's' ' ' 'p' 'u' 'r' 'p' 'o' 's' 'i'] ['v']
# ['s' ' ' 'p' 'u' 'r' 'p' 'o' 's' 'i' 'v'] ['e']
# [' ' 'p' 'u' 'r' 'p' 'o' 's' 'i' 'v' 'e'] ['l']
# ['p' 'u' 'r' 'p' 'o' 's' 'i' 'v' 'e' 'l'] ['y']
# ['u' 'r' 'p' 'o' 's' 'i' 'v' 'e' 'l' 'y'] [' ']
# ['r' 'p' 'o' 's' 'i' 'v' 'e' 'l' 'y' ' '] ['s']
# ['p' 'o' 's' 'i' 'v' 'e' 'l' 'y' ' ' 's'] ['a']
# ['o' 's' 'i' 'v' 'e' 'l' 'y' ' ' 's' 'a'] ['m']
# ['s' 'i' 'v' 'e' 'l' 'y' ' ' 's' 'a' 'm'] ['p']
# ['i' 'v' 'e' 'l' 'y' ' ' 's' 'a' 'm' 'p'] ['l']
# ['v' 'e' 'l' 'y' ' ' 's' 'a' 'm' 'p' 'l'] ['e']
# ['e' 'l' 'y' ' ' 's' 'a' 'm' 'p' 'l' 'e'] ['d']
# ['l' 'y' ' ' 's' 'a' 'm' 'p' 'l' 'e' 'd'] [' ']
# ['y' ' ' 's' 'a' 'm' 'p' 'l' 'e' 'd' ' '] ['d']
# [' ' 's' 'a' 'm' 'p' 'l' 'e' 'd' ' ' 'd'] ['a']
# ['s' 'a' 'm' 'p' 'l' 'e' 'd' ' ' 'd' 'a'] ['t']
# ['a' 'm' 'p' 'l' 'e' 'd' ' ' 'd' 'a' 't'] ['a']
# ['m' 'p' 'l' 'e' 'd' ' ' 'd' 'a' 't' 'a'] [' ']
# ['p' 'l' 'e' 'd' ' ' 'd' 'a' 't' 'a' ' '] ['s']
# ['l' 'e' 'd' ' ' 'd' 'a' 't' 'a' ' ' 's'] ['e']
# ['e' 'd' ' ' 'd' 'a' 't' 'a' ' ' 's' 'e'] ['t']
# ['d' ' ' 'd' 'a' 't' 'a' ' ' 's' 'e' 't'] ['.']
# [' ' 'd' 'a' 't' 'a' ' ' 's' 'e' 't' '.'] [' ']
# ['d' 'a' 't' 'a' ' ' 's' 'e' 't' '.' ' '] ['t']
# ['a' 't' 'a' ' ' 's' 'e' 't' '.' ' ' 't'] ['h']
# ['t' 'a' ' ' 's' 'e' 't' '.' ' ' 't' 'h'] ['i']
# ['a' ' ' 's' 'e' 't' '.' ' ' 't' 'h' 'i'] ['s']
# [' ' 's' 'e' 't' '.' ' ' 't' 'h' 'i' 's'] [' ']
# ['s' 'e' 't' '.' ' ' 't' 'h' 'i' 's' ' '] ['t']
# ['e' 't' '.' ' ' 't' 'h' 'i' 's' ' ' 't'] ['a']
# ['t' '.' ' ' 't' 'h' 'i' 's' ' ' 't' 'a'] ['x']
# ['.' ' ' 't' 'h' 'i' 's' ' ' 't' 'a' 'x'] ['o']
# [' ' 't' 'h' 'i' 's' ' ' 't' 'a' 'x' 'o'] ['n']
# ['t' 'h' 'i' 's' ' ' 't' 'a' 'x' 'o' 'n'] ['o']
# ['h' 'i' 's' ' ' 't' 'a' 'x' 'o' 'n' 'o'] ['m']
# ['i' 's' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm'] ['y']
# ['s' ' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y'] [' ']
# [' ' 't' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' '] ['p']
# ['t' 'a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 'p'] ['r']
# ['a' 'x' 'o' 'n' 'o' 'm' 'y' ' ' 'p' 'r'] ['o']
# ['x' 'o' 'n' 'o' 'm' 'y' ' ' 'p' 'r' 'o'] ['v']
# ['o' 'n' 'o' 'm' 'y' ' ' 'p' 'r' 'o' 'v'] ['i']
# ['n' 'o' 'm' 'y' ' ' 'p' 'r' 'o' 'v' 'i'] ['d']
# ['o' 'm' 'y' ' ' 'p' 'r' 'o' 'v' 'i' 'd'] ['e']
# ['m' 'y' ' ' 'p' 'r' 'o' 'v' 'i' 'd' 'e'] ['s']
# ['y' ' ' 'p' 'r' 'o' 'v' 'i' 'd' 'e' 's'] [' ']
# [' ' 'p' 'r' 'o' 'v' 'i' 'd' 'e' 's' ' '] ['a']
# ['p' 'r' 'o' 'v' 'i' 'd' 'e' 's' ' ' 'a'] [' ']
# ['r' 'o' 'v' 'i' 'd' 'e' 's' ' ' 'a' ' '] ['c']
# ['o' 'v' 'i' 'd' 'e' 's' ' ' 'a' ' ' 'c'] ['o']
# ['v' 'i' 'd' 'e' 's' ' ' 'a' ' ' 'c' 'o'] ['d']
# ['i' 'd' 'e' 's' ' ' 'a' ' ' 'c' 'o' 'd'] ['i']
# ['d' 'e' 's' ' ' 'a' ' ' 'c' 'o' 'd' 'i'] ['n']
# ['e' 's' ' ' 'a' ' ' 'c' 'o' 'd' 'i' 'n'] ['g']
# ['s' ' ' 'a' ' ' 'c' 'o' 'd' 'i' 'n' 'g'] [' ']
# [' ' 'a' ' ' 'c' 'o' 'd' 'i' 'n' 'g' ' '] ['s']
# ['a' ' ' 'c' 'o' 'd' 'i' 'n' 'g' ' ' 's'] ['c']
# [' ' 'c' 'o' 'd' 'i' 'n' 'g' ' ' 's' 'c'] ['h']
# ['c' 'o' 'd' 'i' 'n' 'g' ' ' 's' 'c' 'h'] ['e']
# ['o' 'd' 'i' 'n' 'g' ' ' 's' 'c' 'h' 'e'] ['m']
# ['d' 'i' 'n' 'g' ' ' 's' 'c' 'h' 'e' 'm'] ['e']
# ['i' 'n' 'g' ' ' 's' 'c' 'h' 'e' 'm' 'e'] [' ']
# ['n' 'g' ' ' 's' 'c' 'h' 'e' 'm' 'e' ' '] ['f']
# ['g' ' ' 's' 'c' 'h' 'e' 'm' 'e' ' ' 'f'] ['o']
# [' ' 's' 'c' 'h' 'e' 'm' 'e' ' ' 'f' 'o'] ['r']
# ['s' 'c' 'h' 'e' 'm' 'e' ' ' 'f' 'o' 'r'] [' ']
# ['c' 'h' 'e' 'm' 'e' ' ' 'f' 'o' 'r' ' '] ['o']
# ['h' 'e' 'm' 'e' ' ' 'f' 'o' 'r' ' ' 'o'] ['t']
# ['e' 'm' 'e' ' ' 'f' 'o' 'r' ' ' 'o' 't'] ['h']
# ['m' 'e' ' ' 'f' 'o' 'r' ' ' 'o' 't' 'h'] ['e']
# ['e' ' ' 'f' 'o' 'r' ' ' 'o' 't' 'h' 'e'] ['r']
# [' ' 'f' 'o' 'r' ' ' 'o' 't' 'h' 'e' 'r'] [' ']
# ['f' 'o' 'r' ' ' 'o' 't' 'h' 'e' 'r' ' '] ['r']
# ['o' 'r' ' ' 'o' 't' 'h' 'e' 'r' ' ' 'r'] ['e']
# ['r' ' ' 'o' 't' 'h' 'e' 'r' ' ' 'r' 'e'] ['s']
# [' ' 'o' 't' 'h' 'e' 'r' ' ' 'r' 'e' 's'] ['e']
# ['o' 't' 'h' 'e' 'r' ' ' 'r' 'e' 's' 'e'] ['a']
# ['t' 'h' 'e' 'r' ' ' 'r' 'e' 's' 'e' 'a'] ['r']
# ['h' 'e' 'r' ' ' 'r' 'e' 's' 'e' 'a' 'r'] ['c']
# ['e' 'r' ' ' 'r' 'e' 's' 'e' 'a' 'r' 'c'] ['h']
# ['r' ' ' 'r' 'e' 's' 'e' 'a' 'r' 'c' 'h'] ['e']
# [' ' 'r' 'e' 's' 'e' 'a' 'r' 'c' 'h' 'e'] ['r']
# ['r' 'e' 's' 'e' 'a' 'r' 'c' 'h' 'e' 'r'] ['s']
# ['e' 's' 'e' 'a' 'r' 'c' 'h' 'e' 'r' 's'] [',']
# ['s' 'e' 'a' 'r' 'c' 'h' 'e' 'r' 's' ','] [' ']
# ['e' 'a' 'r' 'c' 'h' 'e' 'r' 's' ',' ' '] ['a']
# ['a' 'r' 'c' 'h' 'e' 'r' 's' ',' ' ' 'a'] ['s']
# ['r' 'c' 'h' 'e' 'r' 's' ',' ' ' 'a' 's'] [' ']
# ['c' 'h' 'e' 'r' 's' ',' ' ' 'a' 's' ' '] ['w']
# ['h' 'e' 'r' 's' ',' ' ' 'a' 's' ' ' 'w'] ['e']
# ['e' 'r' 's' ',' ' ' 'a' 's' ' ' 'w' 'e'] ['l']
# ['r' 's' ',' ' ' 'a' 's' ' ' 'w' 'e' 'l'] ['l']
# ['s' ',' ' ' 'a' 's' ' ' 'w' 'e' 'l' 'l'] [' ']
# [',' ' ' 'a' 's' ' ' 'w' 'e' 'l' 'l' ' '] ['a']
# [' ' 'a' 's' ' ' 'w' 'e' 'l' 'l' ' ' 'a'] ['s']
# ['a' 's' ' ' 'w' 'e' 'l' 'l' ' ' 'a' 's'] [' ']
# ['s' ' ' 'w' 'e' 'l' 'l' ' ' 'a' 's' ' '] ['a']
# [' ' 'w' 'e' 'l' 'l' ' ' 'a' 's' ' ' 'a'] [' ']
# ['w' 'e' 'l' 'l' ' ' 'a' 's' ' ' 'a' ' '] ['m']
# ['e' 'l' 'l' ' ' 'a' 's' ' ' 'a' ' ' 'm'] ['a']
# ['l' 'l' ' ' 'a' 's' ' ' 'a' ' ' 'm' 'a'] ['p']
# ['l' ' ' 'a' 's' ' ' 'a' ' ' 'm' 'a' 'p'] [' ']
# [' ' 'a' 's' ' ' 'a' ' ' 'm' 'a' 'p' ' '] ['f']
# ['a' 's' ' ' 'a' ' ' 'm' 'a' 'p' ' ' 'f'] ['o']
# ['s' ' ' 'a' ' ' 'm' 'a' 'p' ' ' 'f' 'o'] ['r']
# [' ' 'a' ' ' 'm' 'a' 'p' ' ' 'f' 'o' 'r'] [' ']
# ['a' ' ' 'm' 'a' 'p' ' ' 'f' 'o' 'r' ' '] ['w']
# [' ' 'm' 'a' 'p' ' ' 'f' 'o' 'r' ' ' 'w'] ['o']
# ['m' 'a' 'p' ' ' 'f' 'o' 'r' ' ' 'w' 'o'] ['r']
# ['a' 'p' ' ' 'f' 'o' 'r' ' ' 'w' 'o' 'r'] ['k']
# ['p' ' ' 'f' 'o' 'r' ' ' 'w' 'o' 'r' 'k'] ['g']
# [' ' 'f' 'o' 'r' ' ' 'w' 'o' 'r' 'k' 'g'] ['r']
# ['f' 'o' 'r' ' ' 'w' 'o' 'r' 'k' 'g' 'r'] ['o']
# ['o' 'r' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o'] ['u']
# ['r' ' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u'] ['p']
# [' ' 'w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p'] [' ']
# ['w' 'o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' '] ['f']
# ['o' 'r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'f'] ['a']
# ['r' 'k' 'g' 'r' 'o' 'u' 'p' ' ' 'f' 'a'] ['c']
# ['k' 'g' 'r' 'o' 'u' 'p' ' ' 'f' 'a' 'c'] ['i']
# ['g' 'r' 'o' 'u' 'p' ' ' 'f' 'a' 'c' 'i'] ['l']
# ['r' 'o' 'u' 'p' ' ' 'f' 'a' 'c' 'i' 'l'] ['i']
# ['o' 'u' 'p' ' ' 'f' 'a' 'c' 'i' 'l' 'i'] ['t']
# ['u' 'p' ' ' 'f' 'a' 'c' 'i' 'l' 'i' 't'] ['a']
# ['p' ' ' 'f' 'a' 'c' 'i' 'l' 'i' 't' 'a'] ['t']
# [' ' 'f' 'a' 'c' 'i' 'l' 'i' 't' 'a' 't'] ['o']
# ['f' 'a' 'c' 'i' 'l' 'i' 't' 'a' 't' 'o'] ['r']
# ['a' 'c' 'i' 'l' 'i' 't' 'a' 't' 'o' 'r'] ['s']
# ['c' 'i' 'l' 'i' 't' 'a' 't' 'o' 'r' 's'] [' ']
# ['i' 'l' 'i' 't' 'a' 't' 'o' 'r' 's' ' '] ['a']
# ['l' 'i' 't' 'a' 't' 'o' 'r' 's' ' ' 'a'] ['i']
# ['i' 't' 'a' 't' 'o' 'r' 's' ' ' 'a' 'i'] ['m']
# ['t' 'a' 't' 'o' 'r' 's' ' ' 'a' 'i' 'm'] ['i']
# ['a' 't' 'o' 'r' 's' ' ' 'a' 'i' 'm' 'i'] ['n']
# ['t' 'o' 'r' 's' ' ' 'a' 'i' 'm' 'i' 'n'] ['g']
# ['o' 'r' 's' ' ' 'a' 'i' 'm' 'i' 'n' 'g'] [' ']
# ['r' 's' ' ' 'a' 'i' 'm' 'i' 'n' 'g' ' '] ['t']
# ['s' ' ' 'a' 'i' 'm' 'i' 'n' 'g' ' ' 't'] ['o']
# [' ' 'a' 'i' 'm' 'i' 'n' 'g' ' ' 't' 'o'] [' ']
# ['a' 'i' 'm' 'i' 'n' 'g' ' ' 't' 'o' ' '] ['d']
# ['i' 'm' 'i' 'n' 'g' ' ' 't' 'o' ' ' 'd'] ['e']
# ['m' 'i' 'n' 'g' ' ' 't' 'o' ' ' 'd' 'e'] ['e']
# ['i' 'n' 'g' ' ' 't' 'o' ' ' 'd' 'e' 'e'] ['p']
# ['n' 'g' ' ' 't' 'o' ' ' 'd' 'e' 'e' 'p'] ['e']
# ['g' ' ' 't' 'o' ' ' 'd' 'e' 'e' 'p' 'e'] ['n']
# [' ' 't' 'o' ' ' 'd' 'e' 'e' 'p' 'e' 'n'] [' ']
# ['t' 'o' ' ' 'd' 'e' 'e' 'p' 'e' 'n' ' '] ['c']
# ['o' ' ' 'd' 'e' 'e' 'p' 'e' 'n' ' ' 'c'] ['o']
# [' ' 'd' 'e' 'e' 'p' 'e' 'n' ' ' 'c' 'o'] ['l']
# ['d' 'e' 'e' 'p' 'e' 'n' ' ' 'c' 'o' 'l'] ['l']
# ['e' 'e' 'p' 'e' 'n' ' ' 'c' 'o' 'l' 'l'] ['a']
# ['e' 'p' 'e' 'n' ' ' 'c' 'o' 'l' 'l' 'a'] ['b']
# ['p' 'e' 'n' ' ' 'c' 'o' 'l' 'l' 'a' 'b'] ['o']
# ['e' 'n' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o'] ['r']
# ['n' ' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r'] ['a']
# [' ' 'c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a'] ['t']
# ['c' 'o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't'] ['i']
# ['o' 'l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i'] ['v']
# ['l' 'l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'v'] ['e']
# ['l' 'a' 'b' 'o' 'r' 'a' 't' 'i' 'v' 'e'] [' ']
# ['a' 'b' 'o' 'r' 'a' 't' 'i' 'v' 'e' ' '] ['c']
# ['b' 'o' 'r' 'a' 't' 'i' 'v' 'e' ' ' 'c'] ['o']
# ['o' 'r' 'a' 't' 'i' 'v' 'e' ' ' 'c' 'o'] ['n']
# ['r' 'a' 't' 'i' 'v' 'e' ' ' 'c' 'o' 'n'] ['v']
# ['a' 't' 'i' 'v' 'e' ' ' 'c' 'o' 'n' 'v'] ['e']
# ['t' 'i' 'v' 'e' ' ' 'c' 'o' 'n' 'v' 'e'] ['r']
# ['i' 'v' 'e' ' ' 'c' 'o' 'n' 'v' 'e' 'r'] ['s']
# ['v' 'e' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's'] ['a']
# ['e' ' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a'] ['t']
# [' ' 'c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't'] ['i']
# ['c' 'o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i'] ['o']
# ['o' 'n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o'] ['n']
# ['n' 'v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n'] ['s']
# ['v' 'e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's'] ['.']
# ['e' 'r' 's' 'a' 't' 'i' 'o' 'n' 's' '.'] ['Ⓔ']
# ['r' 's' 'a' 't' 'i' 'o' 'n' 's' '.' 'Ⓔ'] ['Ⓔ']
# ['s' 'a' 't' 'i' 'o' 'n' 's' '.' 'Ⓔ' 'Ⓔ'] ['Ⓔ']

# %% [markdown]
# to-do, network notes:
#
# create window-size, pad with START tokens
# add EOF token (and remove power/toughness if null?)
# in network, encode name with LSTM(s) then copy state(s) to output network
# (effectively a seq-to-seq)
# generator needs to PAD TO FIXED BATCH SIZE (see length chosen above)
# use batch-training and reset_state
